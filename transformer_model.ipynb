# %%
import pandas as pd 
import numpy as np 
import re
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from collections import Counter
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
file_name='/kaggle/input/movie-genreplotposter/Movie_combined.csv'
df=pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Unnamed: 0                            Title   Genre  \
# 0           0          the great train robbery  action
# 1           1                  the suburbanite  comedy
# 2           2  how brown saw the baseball game  comedy
# 3           5         the adventures of dollie   drama
# 4           6                  the black viper   drama
#
#                                                 Plot  \
# 0  The film opens with two bandits breaking into ...
# 1  The film is about a family who move to the sub...
# 2  Before heading out to a baseball game at a nea...
# 3  On a beautiful summer day a father and mother ...
# 4  A thug accosts a girl as she leaves her workpl...
#
#                                               Poster
# 0  https://m.media-amazon.com/images/M/MV5BOWE4M2...
# 1  https://m.media-amazon.com/images/M/MV5BMTUwOT...
# 2                                                  0
# 3  https://m.media-amazon.com/images/M/MV5BMDlmYz...
# 4  https://m.media-amazon.com/images/M/MV5BZDVjYT...

# %%
df = df[['Title', 'Plot','Genre']]

# %%
df.head()
# Out:
#                              Title  \
# 0          the great train robbery
# 1                  the suburbanite
# 2  how brown saw the baseball game
# 3         the adventures of dollie
# 4                  the black viper
#
#                                                 Plot   Genre
# 0  The film opens with two bandits breaking into ...  action
# 1  The film is about a family who move to the sub...  comedy
# 2  Before heading out to a baseball game at a nea...  comedy
# 3  On a beautiful summer day a father and mother ...   drama
# 4  A thug accosts a girl as she leaves her workpl...   drama

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17303 entries, 0 to 17302
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   17303 non-null  object
#  1   Plot    17303 non-null  object
#  2   Genre   17303 non-null  object
# dtypes: object(3)
# memory usage: 405.7+ KB

# %%
df.describe()
# Out:
#         Title                                               Plot  Genre
# count   17303                                              17303  17303
# unique  16620                                              16584      6
# top      prey  At night, a carnivorous, shape-shifting alien ...  drama
# freq        9                                                  9   5793

# %%
duplicates = df.duplicated()
print(df[duplicates])
# Out:
#                     Title                                               Plot  \
# 33             the escape  The film begins with a short prologue explaini...
# 34             the escape  The film begins with a short prologue explaini...
# 86     great expectations  A young boy, Pip, runs into an escaped convict...
# 112              the cook  Fatty is the head chef at the "Bull Pup" resta...
# 202                  love  A young woman, Natalie Storm (played by Glaum)...
# ...                   ...                                                ...
# 17236               quick  Seoul, 2004. A group of bikers are joy-riding ...
# 17240               blind  A missing person case involving a female unive...
# 17241               blind  A missing person case involving a female unive...
# 17279               honey  In the remote and undeveloped eastern Black Se...
# 17280               honey  In the remote and undeveloped eastern Black Se...
#
#           Genre
# 33        drama
# 34        drama
# 86        drama
# 112      comedy
# 202     romance
# ...         ...
# 17236    action
# 17240  thriller
# 17241  thriller
# 17279     drama
# 17280     drama
#
# [659 rows x 3 columns]

# %%
df = df.drop_duplicates()

# Verify results
print("Duplicates removed. Number of rows:", len(df))
# Out:
# Duplicates removed. Number of rows: 16644

# %%
num_unique_genres = df['Genre'].nunique()
print("Number of unique genres:", num_unique_genres)
# Out:
# Number of unique genres: 6

# %%
genre_counts = df['Genre'].value_counts()
plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Each Genre', fontsize=16)  # Set title font size
plt.xlabel('Genre', fontsize=10)  # Set x-axis label font size
plt.ylabel('Frequency', fontsize=10)  # Set y-axis label font size
plt.xticks(rotation=45, ha='right', fontsize=8)  # Rotate and set x-axis tick label font size
plt.yticks(fontsize=12)  # Set y-axis tick label font size
plt.tight_layout()
plt.show()

# %%
Counter(df["Title"]).most_common()
# Out:
# [('angel', 4),
#  ('romance', 3),
#  ('godzilla', 3),
#  ('darling', 3),
#  ('i love you', 3),
#  ('love', 2),
#  ('the valiant', 2),
#  ('welcome home', 2),
#  ('oh, what a night', 2),
#  ('i, the jury', 2),
#  ('another time, another place', 2),
#  ('tarzan, the ape man', 2),
#  ('see no evil', 2),
#  ('the karate kid', 2),
#  ('mother', 2),
#  ('war', 2),
#  ('london', 2),
#  ('the importance of being earnest', 2),
#  ('the great train robbery', 1),
#  ('the suburbanite', 1),
#  ('how brown saw the baseball game', 1),
#  ('the adventures of dollie', 1),
#  ('the black viper', 1),
#  ('a calamitous elopement', 1),
#  ('the fight for freedom', 1),
#  ('at the altar', 1),
#  ("a drunkard's reformation", 1),
#  ('the golden louis', 1),
#  ('an arcadian maid', 1),
#  ('hemlock hoax, the detective', 1),
#  ('the house with closed shutters', 1),
#  ('a lad from old ireland', 1),
#  ('the black arrow: a tale of the two roses', 1),
#  ('brown of harvard', 1),
#  ('sweet memories', 1),
#  ('the musketeers of pig alley', 1),
#  ('petticoat camp', 1),
#  ('put yourself in his place', 1),
#  ("barney oldfield's race for a life", 1),
#  ("bob's baby", 1),
#  ('cohen saves the flag', 1),
#  ('the quakeress', 1),
#  ('the restless spirit', 1),
#  ('the telephone girl and the lady', 1),
#  ('a busy day', 1),
#  ('the call of the north', 1),
#  ('caught in a cabaret', 1),
#  ('caught in the rain', 1),
#  ('cruel, cruel love', 1),
#  ('dough and dynamite', 1),
#  ('the escape', 1),
#  ('gentlemen of nerve', 1),
#  ('getting acquainted', 1),
#  ("his father's rifle", 1),
#  ('the knockout', 1),
#  ('mabel at the wheel', 1),
#  ("mabel's blunder", 1),
#  ("mabel's married life", 1),
#  ("mabel's strange predicament", 1),
#  ('making a living', 1),
#  ('the masquerader', 1),
#  ('the new janitor', 1),
#  ('the property man', 1),
#  ('rose of the rancho', 1),
#  ('the rounders', 1),
#  ('salomy jane', 1),
#  ('should a woman divorce?', 1),
#  ('those love pangs', 1),
#  ("tillie's punctured romance", 1),
#  ('the wrath of the gods', 1),
#  ('after five', 1),
#  ('carmen', 1),
#  ('enoch arden', 1),
#  ('a fool there was', 1),
#  ('four feathers', 1),
#  ('fresh from the farm', 1),
#  ('giving them fits', 1),
#  ('love, loot and crash', 1),
#  ('the soul of broadway', 1),
#  ('the toast of death', 1),
#  ('the warrens of virginia', 1),
#  ('work', 1),
#  ('the abandonment', 1),
#  ('the bondman', 1),
#  ('civilization', 1),
#  ('a daughter of the gods', 1),
#  ('divorce and the daughter', 1),
#  ('hulda from holland', 1),
#  ('lights of new york', 1),
#  ('manhattan madness', 1),
#  ("the soul's cycle", 1),
#  ('the stepping stone', 1),
#  ('under two flags', 1),
#  ("youth's endearing charm", 1),
#  ('all aboard', 1),
#  ('bucking broadway', 1),
#  ('camille', 1),
#  ("cheyenne's pal", 1),
#  ('the devil-stone', 1),
#  ('easy street', 1),
#  ('golden rule kate', 1),
#  ('great expectations', 1),
#  ('her right to live', 1),
#  ('his wedding night', 1),
#  ('the immigrant', 1),
#  ('in again, out again', 1),
#  ('the jury of fate', 1),
#  ('the man without a country', 1),
#  ('a modern musketeer', 1),
#  ('oh doctor!', 1),
#  ("peggy, the will o' the wisp", 1),
#  ('the poor little rich girl', 1),
#  ('reaching for the moon', 1),
#  ('rebecca of sunnybrook farm', 1),
#  ('a reckless romeo', 1),
#  ('the rough house', 1),
#  ('souls in pawn', 1),
#  ('straight shooting', 1),
#  ('a strange transgressor', 1),
#  ('the woman god forgot', 1),
#  ('all woman', 1),
#  ('amarilly of clothes-line alley', 1),
#  ('are crooks dishonest?', 1),
#  ('believe me, xantippe', 1),
#  ("the bride's awakening", 1),
#  ('cecilia of the pink roses', 1),
#  ('the cook', 1),
#  ('the craving', 1),
#  ('the deciding kiss', 1),
#  ('face value', 1),
#  ('the forbidden city', 1),
#  ('fuss and feathers', 1),
#  ('the goddess of lost lake', 1),
#  ('he comes up smiling', 1),
#  ('hell bent', 1),
#  ('the legion of death', 1),
#  ('moonshine', 1),
#  ('the non-stop kid', 1),
#  ('old wives for new', 1),
#  ('out west', 1),
#  ('the romance of tarzan', 1),
#  ('salomé', 1),
#  ('the scarlet drop', 1),
#  ('set free', 1),
#  ('shoulder arms', 1),
#  ('stella maris', 1),
#  ('tarzan of the apes', 1),
#  ('till i come back to you', 1),
#  ('under the yoke', 1),
#  ("we can't have everything", 1),
#  ('when do we eat?', 1),
#  ('which woman?', 1),
#  ('the whispering chorus', 1),
#  ('ask father', 1),
#  ('better times', 1),
#  ('bolshevism on trial', 1),
#  ('bumping into broadway', 1),
#  ('daddy-long-legs', 1),
#  ('dangerous hours', 1),
#  ("don't change your husband", 1),
#  ('the echo of youth', 1),
#  ('the exquisite thief', 1),
#  ('the false faces', 1),
#  ('for better, for worse', 1),
#  ('from hand to mouth', 1),
#  ('the girl who stayed at home', 1),
#  ('the grim game', 1),
#  ("a gun fightin' gentleman", 1),
#  ('happy though married', 1),
#  ('the haunted bedroom', 1),
#  ('hawthorne of the u.s.a.', 1),
#  ("heart o' the hills", 1),
#  ('his majesty, the american', 1),
#  ('the law of men', 1),
#  ('male and female', 1),
#  ("a man's fight", 1),
#  ('the miracle of love', 1),
#  ('pistols for breakfast', 1),
#  ('the probation wife', 1),
#  ('ravished armenia', 1),
#  ('the roaring road', 1),
#  ('a romance of happy valley', 1),
#  ('scarlet days', 1),
#  ('a society exile', 1),
#  ('soldiers of fortune', 1),
#  ('sunnyside', 1),
#  ('the test of honor', 1),
#  ('true heart susie', 1),
#  ('the turn in the road', 1),
#  ('the unpainted woman', 1),
#  ('the virtuous thief', 1),
#  ('what every woman learns', 1),
#  ('when the clouds roll by', 1),
#  ('the white heather', 1),
#  ('the world and its woman', 1),
#  ('yankee doodle in berlin', 1),
#  ("you're fired", 1),
#  ('april folly', 1),
#  ('blind youth', 1),
#  ('a child for sale', 1),
#  ('convict 13', 1),
#  ("the devil's pass key", 1),
#  ('the false road', 1),
#  ('the family honor', 1),
#  ('the girl in number 29', 1),
#  ('hairpins', 1),
#  ('haunted spooks', 1),
#  ("her husband's friend", 1),
#  ('high and dizzy', 1),
#  ('huckleberry finn', 1),
#  ('the idol dancer', 1),
#  ('in the heart of a fool', 1),
#  ('the jack-knife man', 1),
#  ("judy of rogue's harbor", 1),
#  ("lady rose's daughter", 1),
#  ('the love flower', 1),
#  ('number, please?', 1),
#  ('pollyanna', 1),
#  ('remodeling her husband', 1),
#  ('the round-up', 1),
#  ('the saphead', 1),
#  ('sex', 1),
#  ('shore acres', 1),
#  ('silk hosiery', 1),
#  ('silk husbands and calico wives', 1),
#  ('the slim princess', 1),
#  ('something to think about', 1),
#  ('a splendid hazard', 1),
#  ('suds', 1),
#  ('the virgin of stamboul', 1),
#  ('why change your wife?', 1),
#  ('within our gates', 1),
#  ('the woman in the suitcase', 1),
#  ('the affairs of anatol', 1),
#  ('among those present', 1),
#  ('the big punch', 1),
#  ('the blot', 1),
#  ('the boat', 1),
#  ('experience', 1),
#  ('forbidden fruit', 1),
#  ('forever', 1),
#  ('the four horsemen of the apocalypse', 1),
#  ('the goat', 1),
#  ('the haunted house', 1),
#  ('heedless moths', 1),
#  ('i do', 1),
#  ('the lotus eater', 1),
#  ('the love light', 1),
#  ('love never dies', 1),
#  ('the lucky dog', 1),
#  ("mother o' mine", 1),
#  ('never weaken', 1),
#  ('no woman knows', 1),
#  ('the nut', 1),
#  ('orphans of the storm', 1),
#  ('the playhouse', 1),
#  ('roads of destiny', 1),
#  ('a sailor-made man', 1),
#  ('the sea lion', 1),
#  ('seven years bad luck', 1),
#  ('sheltered daughters', 1),
#  ('the silver lining', 1),
#  ('the sky pilot', 1),
#  ('sure fire', 1),
#  ("tol'able david", 1),
#  ('uncharted seas', 1),
#  ("woman's place", 1),
#  ('beyond the rocks', 1),
#  ('a blind bargain', 1),
#  ('daydreams', 1),
#  ('dr. jack', 1),
#  ('dusk to dawn', 1),
#  ('the electric house', 1),
#  ('fair lady', 1),
#  ('foolish wives', 1),
#  ('the loaded door', 1),
#  ('moran of the lady letty', 1),
#  ('pay day', 1),
#  ('peacock alley', 1),
#  ("peg o' my heart", 1),
#  ("ridin' wild", 1),
#  ('trifling women', 1),
#  ('wildness of youth', 1),
#  ('the woman he married', 1),
#  ('the young rajah', 1),
#  ("ambrose applejohn's adventure", 1),
#  ('ashes of vengeance', 1),
#  ('the balloonatic', 1),
#  ('black oxen', 1),
#  ('the call of the canyon', 1),
#  ('the daring years', 1),
#  ('the extra girl', 1),
#  ('gentle julia', 1),
#  ('our hospitality', 1),
#  ('the pilgrim', 1),
#  ('safety last!', 1),
#  ('the shock', 1),
#  ('the shriek of araby', 1),
#  ('the silent command', 1),
#  ('slippy mcgee', 1),
#  ('souls for sale', 1),
#  ('three ages', 1),
#  ('why worry?', 1),
#  ('the arab', 1),
#  ('circe, the enchantress', 1),
#  ('the enchanted cottage', 1),
#  ('feet of clay', 1),
#  ('greed', 1),
#  ('he who gets slapped', 1),
#  ("helen's babies", 1),
#  ('her night of romance', 1),
#  ('his hour', 1),
#  ('hot water', 1),
#  ('the iron horse', 1),
#  ("isn't life wonderful", 1),
#  ('manhandled', 1),
#  ('monsieur beaucaire', 1),
#  ('the navigator', 1),
#  ('one night in rome', 1),
#  ('the red lily', 1),
#  ('romola', 1),
#  ('sherlock, jr.', 1),
#  ('the shooting of dan mcgrew', 1),
#  ('wild oranges', 1),
#  ('the yankee consul', 1),
#  ('the big parade', 1),
#  ('cheaper to marry', 1),
#  ('confessions of a queen', 1),
#  ('the dark angel', 1),
#  ('fifty-fifty', 1),
#  ("hogan's alley", 1),
#  ('kentucky pride', 1),
#  ('the lady', 1),
#  ("lady windermere's fan", 1),
#  ('little annie rooney', 1),
#  ('the lucky horseshoe', 1),
#  ('the mad whirl', 1),
#  ('the mystic', 1),
#  ('old clothes', 1),
#  ('phantom of the opera', 1),
#  ('the rag man', 1),
#  ('sally, irene and mary', 1),
#  ('sally of the sawdust', 1),
#  ('the salvation hunters', 1),
#  ('seven chances', 1),
#  ('smouldering fires', 1),
#  ('stage struck', 1),
#  ('time, the comedian', 1),
#  ('too many kisses', 1),
#  ('the tower of lies', 1),
#  ('the trail rider', 1),
#  ('wolf blood', 1),
#  ('battling butler', 1),
#  ("the better 'ole", 1),
#  ('beverly of graustark', 1),
#  ('the blackbird', 1),
#  ('la bohème', 1),
#  ('the boy friend', 1),
#  ('cruise of the jasper b', 1),
#  ('dance madness', 1),
#  ('don juan', 1),
#  ('ella cinders', 1),
#  ('the exquisite sinner', 1),
#  ('fine manners', 1),
#  ('flesh and the devil', 1),
#  ("for heaven's sake", 1),
#  ('the gay deceiver', 1),
#  ('the general', 1),
#  ('the great k & a train robbery', 1),
#  ('hands up!', 1),
#  ('high steppers', 1),
#  ('the joy girl', 1),
#  ('kid boots', 1),
#  ('looking for trouble', 1),
#  ('the magician', 1),
#  ('mare nostrum', 1),
#  ("miss brewster's millions", 1),
#  ('old ironsides', 1),
#  ('private izzy murphy', 1),
#  ('the sea beast', 1),
#  ('so this is paris', 1),
#  ("so's your old man", 1),
#  ('the strong man', 1),
#  ('the temptress', 1),
#  ('torrent', 1),
#  ('tramp, tramp, tramp', 1),
#  ('the winning of barbara worth', 1),
#  ('adam and evil', 1),
#  ('children of divorce', 1),
#  ('the enemy', 1),
#  ('the fair co-ed', 1),
#  ('for the love of mike', 1),
#  ('foreign devils', 1),
#  ('the garden of allah', 1),
#  ('his first flame', 1),
#  ('the kid brother', 1),
#  ('knockout reilly', 1),
#  ('a little journey', 1),
#  ('london after midnight', 1),
#  ('long pants', 1),
#  ('the love of sunya', 1),
#  ('the red mill', 1),
#  ('resurrection', 1),
#  ('the road to romance', 1),
#  ('rookies', 1),
#  ('the show', 1),
#  ('sunrise: a song of two humans', 1),
#  ('the way of all flesh', 1),
#  ('why girls love sailors', 1),
#  ('wings', 1),
#  ('the yankee clipper', 1),
#  ('4 devils', 1),
#  ('the air circus', 1),
#  ('the barker', 1),
#  ('beware of bachelors', 1),
#  ('the cardboard lover', 1),
#  ('the cavalier', 1),
#  ('the crimson city', 1),
#  ('the crowd', 1),
#  ('the divine woman', 1),
#  ('the docks of new york', 1),
#  ("don't marry", 1),
#  ('doomsday', 1),
#  ('drums of love', 1),
#  ('dry martini', 1),
#  ('forbidden hours', 1),
#  ('four sons', 1),
#  ('four walls', 1),
#  ('the garden of eden', 1),
#  ('glorious betsy', 1),
#  ('the godless girl', 1),
#  ('half a bride', 1),
#  ('heart trouble', 1),
#  ('a lady of chance', 1),
#  ('the last command', 1),
#  ('laugh, clown, laugh', 1),
#  ('the law of the range', 1),
#  ('the legion of the condemned', 1),
#  ('lilac time', 1),
#  ('the lion and the mouse', 1),
#  ('love me and the world is mine', 1),
#  ('the magnificent flirt', 1),
#  ('the man who laughs', 1),
#  ('the matinee idol', 1),
#  ('the mating call', 1),
#  ('my man', 1),
#  ('naughty baby', 1),
#  ("noah's ark", 1),
#  ('on trial', 1),
#  ('our dancing daughters', 1),
#  ('the red dance', 1),
#  ('red hair', 1),
#  ('sadie thompson', 1),
#  ('say it with sables', 1),
#  ('sharp shooters', 1),
#  ('show girl', 1),
#  ('show people', 1),
#  ('the singing fool', 1),
#  ('the smart set', 1),
#  ('so this is love?', 1),
#  ('speedy', 1),
#  ('steamboat bill, jr.', 1),
#  ('stop that man!', 1),
#  ('street angel', 1),
#  ('that certain thing', 1),
#  ('we faw down', 1),
#  ('the wedding march', 1),
#  ('west of zanzibar', 1),
#  ('west point', 1),
#  ('wife savers', 1),
#  ('the wind', 1),
#  ('a woman of affairs', 1),
#  ('acquitted', 1),
#  ('the aviator', 1),
#  ('berth marks', 1),
#  ('captain lash', 1),
#  ('careers', 1),
#  ('the case of lena smith', 1),
#  ('children of the ritz', 1),
#  ('coquette', 1),
#  ('desert nights', 1),
#  ('disraeli', 1),
#  ('drag', 1),
#  ('dynamite', 1),
#  ('fancy baggage', 1),
#  ('the forward pass', 1),
#  ('the gamblers', 1),
#  ('the great divide', 1),
#  ('half marriage', 1),
#  ('hallelujah!', 1),
#  ('hardboiled rose', 1),
#  ('his glorious night', 1),
#  ('jazz heaven', 1),
#  ('lady of the pavements', 1),
#  ('the letter', 1),
#  ('the locked door', 1),
#  ('masked emotions', 1),
#  ("new year's eve", 1),
#  ('night parade', 1),
#  ('one hysterical night', 1),
#  ('our modern maidens', 1),
#  ('the pagan', 1),
#  ('queen kelly', 1),
#  ('redskin', 1),
#  ('the river', 1),
#  ('seven faces', 1),
#  ('seven footprints to satan', 1),
#  ('show boat', 1),
#  ('the sky hawk', 1),
#  ("smilin' guns", 1),
#  ('smiling irish eyes', 1),
#  ('spite marriage', 1),
#  ('the squall', 1),
#  ('stark mad', 1),
#  ('street girl', 1),
#  ('synthetic sin', 1),
#  ('this is heaven', 1),
#  ('the trespasser', 1),
#  ('under the southern cross', 1),
#  ('the very idea', 1),
#  ('wedding rings', 1),
#  ('welcome danger', 1),
#  ('where east is east', 1),
#  ('why be good?', 1),
#  ('wild orchids', 1),
#  ('the wolf song', 1),
#  ('woman trap', 1),
#  ('the younger generation', 1),
#  ('abraham lincoln', 1),
#  ('animal crackers', 1),
#  ('anna christie', 1),
#  ('beau bandit', 1),
#  ('behind the make-up', 1),
#  ('the benson murder case', 1),
#  ('the big house', 1),
#  ('the big trail', 1),
#  ('borrowed wives', 1),
#  ('the boudoir diplomat', 1),
#  ('the case of sergeant grischa', 1),
#  ('check and double check', 1),
#  ('courage', 1),
#  ('the devil to pay!', 1),
#  ("the devil's holiday", 1),
#  ('the divorcee', 1),
#  ('doughboys', 1),
#  ('dumbbells in ermine', 1),
#  ('extravagance', 1),
#  ('the fall guy', 1),
#  ('feet first', 1),
#  ('the florodora girl', 1),
#  ('for the defense', 1),
#  ('general crack', 1),
#  ('girl of the port', 1),
#  ('the girl said no', 1),
#  ('the green goddess', 1),
#  ('grumpy', 1),
#  ('half shot at sunrise', 1),
#  ('he knew women', 1),
#  ('hell harbor', 1),
#  ("hell's heroes", 1),
#  ('hide-out', 1),
#  ('hit the deck', 1),
#  ('hook, line and sinker', 1),
#  ('hot curves', 1),
#  ('isle of escape', 1),
#  ("journey's end", 1),
#  ('a lady surrenders', 1),
#  ('a lady to love', 1),
#  ('the lash', 1),
#  ('laughter', 1),
#  ('lawful larceny', 1),
#  ("lovin' the ladies", 1),
#  ('madam satan', 1),
#  ('mamba', 1),
#  ("the man from blankley's", 1),
#  ('a man from wyoming', 1),
#  ('the man hunter', 1),
#  ('the matrimonial bed', 1),
#  ('montana moon', 1),
#  ('morocco', 1),
#  ('mothers cry', 1),
#  ("near the rainbow's end", 1),
#  ('the office wife', 1),
#  ('oh sailor behave', 1),
#  ('oklahoma cyclone', 1),
#  ('on your back', 1),
#  ("one night at susie's", 1),
#  ('the other tomorrow', 1),
#  ('our blushing brides', 1),
#  ('outside the law', 1),
#  ('outward bound', 1),
#  ('part time wife', 1),
#  ('the pay-off', 1),
#  ('playing around', 1),
#  ("river's end", 1),
#  ('road to paradise', 1),
#  ('rough romance', 1),
#  ('rough waters', 1),
#  ('the runaway bride', 1),
#  ('the sap from syracuse', 1),
#  ('sarah and son', 1),
#  ('the sea god', 1),
#  ('second choice', 1),
#  ('second wife', 1),
#  ("she's my weakness", 1),
#  ('the silver horde', 1),
#  ('sin takes a holiday', 1),
#  ('the social lion', 1),
#  ('son of the gods', 1),
#  ('soup to nuts', 1),
#  ('street of chance', 1),
#  ('such men are dangerous', 1),
#  ('sweet mama', 1),
#  ('the texan', 1),
#  ('those three french girls', 1),
#  ('tom sawyer', 1),
#  ('troopers three', 1),
#  ('the way of all men', 1),
#  ('what men want', 1),
#  ('wide open', 1),
#  ('young eagles', 1),
#  ('young man of manhattan', 1),
#  ('24 hours', 1),
#  ('alexander hamilton', 1),
#  ('ambassador bill', 1),
#  ("annabelle's affairs", 1),
#  ('are these our children?', 1),
#  ('arrowsmith', 1),
#  ('the avenger', 1),
#  ('bachelor apartment', 1),
#  ('the bachelor father', 1),
#  ('bad girl', 1),
#  ('bad sister', 1),
#  ('beau ideal', 1),
#  ('behind office doors', 1),
#  ('beyond victory', 1),
#  ('the big shot', 1),
#  ('blonde crazy', 1),
#  ('body and soul', 1),
#  ('border law', 1),
#  ('born to love', 1),
#  ('bought', 1),
#  ('broadminded', 1),
#  ('captain applejack', 1),
#  ('caught cheating', 1),
#  ('caught plastered', 1),
#  ('chances', 1),
#  ('the common law', 1),
#  ('confessions of a co-ed', 1),
#  ('consolation marriage', 1),
#  ('cracked nuts', 1),
#  ('daughter of the dragon', 1),
#  ('devotion', 1),
#  ('dirigible', 1),
#  ("don't bet on women", 1),
#  ('the easiest way', 1),
#  ('east lynne', 1),
#  ('east of borneo', 1),
#  ("everything's rosie", 1),
#  ('the false madonna', 1),
#  ('fighting caravans', 1),
#  ('the fighting marshal', 1),
#  ('five star final', 1),
#  ('flying high', 1),
#  ('a free soul', 1),
#  ('freighters of destiny', 1),
#  ('friends and lovers', 1),
#  ('the front page', 1),
#  ("gentleman's fate", 1),
#  ('girls about town', 1),
#  ('goldie', 1),
#  ('his woman', 1),
#  ('a holy terror', 1),
#  ('honor among lovers', 1),
#  ('a house divided', 1),
#  ('illicit', 1),
#  ('inspiration', 1),
#  ('it pays to advertise', 1),
#  ('just a gigolo', 1),
#  ('kept husbands', 1),
#  ('ladies of the big house', 1),
#  ('the lady refuses', 1),
#  ('the last flight', 1),
#  ('laugh and get rich', 1),
#  ('laughing sinners', 1),
#  ('local boy makes good', 1),
#  ('lonely wives', 1),
#  ('the magnificent lie', 1),
#  ('the maltese falcon', 1),
#  ('the man in possession', 1),
#  ('man of the world', 1),
#  ('mata hari', 1),
#  ('men in her life', 1),
#  ('millie', 1),
#  ('the miracle woman', 1),
#  ('monkey business', 1),
#  ('mr. lemon of orange', 1),
#  ('my sin', 1),
#  ('the naughty flirt', 1),
#  ('nice women', 1),
#  ('night nurse', 1),
#  ("other men's women", 1),
#  ('the painted desert', 1),
#  ('pardon us', 1),
#  ('parlor, bedroom and bath', 1),
#  ("peach o'reno", 1),
#  ('platinum blonde', 1),
#  ('possessed', 1),
#  ('reducing', 1),
#  ('the road to singapore', 1),
#  ('the royal bed', 1),
#  ('the runaround', 1),
#  ('safe in hell', 1),
#  ('salvation nell', 1),
#  ('scandal sheet', 1),
#  ('the sea ghost', 1),
#  ('secret service', 1),
#  ('seed', 1),
#  ('the sin of madelon claudet', 1),
#  ('the sin ship', 1),
#  ('sky raiders', 1),
#  ('son of india', 1),
#  ('strangers may kiss', 1),
#  ('street scene', 1),
#  ('strictly dishonorable', 1),
#  ('suicide fleet', 1),
#  ('susan lenox (her fall and rise)', 1),
#  ('sweepstakes', 1),
#  ('tabu', 1),
#  ('tarnished lady', 1),
#  ('this modern age', 1),
#  ('three who loved', 1),
#  ('the tip-off', 1),
#  ('tonight or never', 1),
#  ('transgression', 1),
#  ('traveling husbands', 1),
#  ('the unholy garden', 1),
#  ('up for murder', 1),
#  ('the viking', 1),
#  ('west of broadway', 1),
#  ('the woman between', 1),
#  ('women of all nations', 1),
#  ('working girls', 1),
#  ('the yellow ticket', 1),
#  ("young donovan's kid", 1),
#  ('20,000 years in sing sing', 1),
#  ('after the ball', 1),
#  ('after tomorrow', 1),
#  ('the age of consent', 1),
#  ('the all american', 1),
#  ('almost married', 1),
#  ('american madness', 1),
#  ('the animal kingdom', 1),
#  ('are you listening?', 1),
#  ('as you desire me', 1),
#  ('big city blues', 1),
#  ('blessed event', 1),
#  ('blonde venus', 1),
#  ('broadway to cheyenne', 1),
#  ('broken lullaby', 1),
#  ('business and pleasure', 1),
#  ('but the flesh is weak', 1),
#  ('the cabin in the cotton', 1),
#  ('call her savage', 1),
#  ('cock of the air', 1),
#  ('come on danger!', 1),
#  ('the conquerors', 1),
#  ('cowboy counsellor', 1),
#  ('the crash', 1),
#  ('the crusader', 1),
#  ('cynara', 1),
#  ('dancers in the dark', 1),
#  ('daring danger', 1),
#  ('devil and the deep', 1),
#  ('the devil is driving', 1),
#  ("devil's lottery", 1),
#  ('disorderly conduct', 1),
#  ('downstairs', 1),
#  ('evenings for sale', 1),
#  ('faithless', 1),
#  ('fast life', 1),
#  ('flowers and trees', 1),
#  ('frisco jenny', 1),
#  ('grand hotel', 1),
#  ('the greeks had a word for them', 1),
#  ('the heart of new york', 1),
#  ("hell's highway", 1),
#  ("hell's house", 1),
#  ('heritage of the desert', 1),
#  ('high pressure', 1),
#  ('horse feathers', 1),
#  ('hot saturday', 1),
#  ('huddle', 1),
#  ('i am a fugitive from a chain gang', 1),
#  ('island of lost souls', 1),
#  ("it's tough to be famous", 1),
#  ('klondike', 1),
#  ('kongo', 1),
#  ('ladies of the jury', 1),
#  ('lady with a past', 1),
#  ('the last mile', 1),
#  ('lawyer man', 1),
#  ('life begins', 1),
#  ('love in high gear', 1),
#  ('madame butterfly', 1),
#  ('make me a star', 1),
#  ('manhattan tower', 1),
#  ('the man called back', 1),
#  ('man wanted', 1),
#  ('the man who played god', 1),
#  ('the match king', 1),
#  ('me and my gal', 1),
#  ('men of chance', 1),
#  ('million dollar legs', 1),
#  ('misleading lady', 1),
#  ('the monster walks', 1),
#  ('movie crazy', 1),
#  ('mr. robinson crusoe', 1),
#  ('my pal, the king', 1),
#  ('new morals for old', 1),
#  ('night world', 1),
#  ('no man of her own', 1),
#  ('no more orchids', 1),
#  ('once in a lifetime', 1),
#  ('one way passage', 1),
#  ('out of singapore', 1),
#  ('the painted woman', 1),
#  ('the passionate plumber', 1),
#  ('the phantom president', 1),
#  ('police court', 1),
#  ('polly of the circus', 1),
#  ('rackety rax', 1),
#  ('rain', 1),
#  ('rasputin and the empress', 1),
#  ('red dust', 1),
#  ('red-headed woman', 1),
#  ('the rich are always with us', 1),
#  ('ride him, cowboy', 1),
#  ("ridin' for justice", 1),
#  ('rockabye', 1),
#  ('scarlet dawn', 1),
#  ('silver dollar', 1),
#  ('sinners in the sun', 1),
#  ('sky bride', 1),
#  ('sky devils', 1),
#  ('skyscraper souls', 1),
#  ("smilin' through", 1),
#  ('speak easily', 1),
#  ("state's attorney", 1),
#  ('the stoker', 1),
#  ('the strange case of clara deane', 1),
#  ('strange interlude', 1),
#  ('a successful calamity', 1),
#  ('symphony of six million', 1),
#  ('tarzan the ape man', 1),
#  ('taxi!', 1),
#  ('the tenderfoot', 1),
#  ('texas cyclone', 1),
#  ('they call it sin', 1),
#  ('they just had to get married', 1),
#  ('they never come back', 1),
#  ('thirteen women', 1),
#  ('this is the night', 1),
#  ('tiger shark', 1),
#  ('tom brown of culver', 1),
#  ('two against the world', 1),
#  ('two-fisted law', 1),
#  ('unashamed', 1),
#  ('union depot', 1),
#  ('uptown new york', 1),
#  ('virtue', 1),
#  ('washington merry-go-round', 1),
#  ('westward passage', 1),
#  ('the wet parade', 1),
#  ('what price hollywood?', 1),
#  ('while paris sleeps', 1),
#  ('white zombie', 1),
#  ('you said a mouthful', 1),
#  ('after tonight', 1),
#  ('aggie appleby, maker of men', 1),
#  ('air hostess', 1),
#  ("ann carver's profession", 1),
#  ('ann vickers', 1),
#  ('baby face', 1),
#  ('the barbarian', 1),
#  ('beauty for sale', 1),
#  ('before dawn', 1),
#  ('blondie johnson', 1),
#  ('brief moment', 1),
#  ('broadway bad', 1),
#  ('bureau of missing persons', 1),
#  ('by candlelight', 1),
#  ('chance at heaven', 1),
#  ('child of manhattan', 1),
#  ('christopher bean', 1),
#  ('christopher strong', 1),
#  ('the cohens and kellys in trouble', 1),
#  ('college coach', 1),
#  ('convention city', 1),
#  ('counsellor at law', 1),
#  ('damaged lives', 1),
#  ('deluge', 1),
#  ("the devil's brother", 1),
#  ('diplomaniacs', 1),
#  ("don't bet on love", 1),
#  ("dora's dunking doughnuts", 1),
#  ('duck soup', 1),
#  ('elmer, the great', 1),
#  ('the emperor jones', 1),
#  ("employees' entrance", 1),
#  ('eskimo', 1),
#  ('ex-lady', 1),
#  ('fast workers', 1),
#  ('flying devils', 1),
#  ('forgotten', 1),
#  ('golden harvest', 1),
#  ('goodbye love', 1),
#  ('havana widows', 1),
#  ('headline shooter', 1),
#  ('heroes for sale', 1),
#  ('his private secretary', 1),
#  ('i cover the waterfront', 1),
#  ('i have lived', 1),
#  ('i loved a woman', 1),
#  ('if i were free', 1),
#  ('infernal machine', 1),
#  ('king of the arena', 1),
#  ("the king's vacation", 1),
#  ('lady for a day', 1),
#  ('laughing at life', 1),
#  ('laughter in hell', 1),
#  ('the life of jimmy dolan', 1),
#  ('looking forward', 1),
#  ('the mad game', 1),
#  ('the man from monterey', 1),
#  ('man of the forest', 1),
#  ('meet the baron', 1),
#  ('midnight mary', 1),
#  ('the midnight patrol', 1),
#  ('mr. broadway', 1),
#  ('murders in the zoo', 1),
#  ('mystery of the wax museum', 1),
#  ('night flight', 1),
#  ('night of terror', 1),
#  ('no other woman', 1),
#  ('only yesterday', 1),
#  ('our betters', 1),
#  ('parachute jumper', 1),
#  ('parole girl', 1),
#  ('the past of mary holmes', 1),
#  ('picture brides', 1),
#  ('picture snatcher', 1),
#  ('pleasure cruise', 1),
#  ('the prizefighter and the lady', 1),
#  ('queen christina', 1),
#  ('sagebrush trail', 1),
#  ("saturday's millions", 1),
#  ('the secret of madame blanche', 1),
#  ('shanghai madness', 1),
#  ('she had to say yes', 1),
#  ('the silk express', 1),
#  ('skyway', 1),
#  ('so this is africa', 1),
#  ('the solitaire man', 1),
#  ('the son of kong', 1),
#  ('sons of the desert', 1),
#  ('stage mother', 1),
#  ('the story of temple drake', 1),
#  ('supernatural', 1),
#  ('sweepings', 1),
#  ('three-cornered moon', 1),
#  ('three little pigs', 1),
#  ('the thrill hunter', 1),
#  ('tillie and gus', 1),
#  ('to the last man', 1),
#  ('topaze', 1),
#  ('turn back the clock', 1),
#  ("the warrior's husband", 1),
#  ('what! no beer?', 1),
#  ('when ladies meet', 1),
#  ('wild boys of the road', 1),
#  ('the working man', 1),
#  ('zoo in budapest', 1),
#  ('affairs of a gentleman', 1),
#  ('as the earth turns', 1),
#  ('beggars in ermine', 1),
#  ('the captain hates the sea', 1),
#  ("the cat's-paw", 1),
#  ('cheating cheaters', 1),
#  ('cockeyed cavaliers', 1),
#  ('college rhythm', 1),
#  ('come on marines!', 1),
#  ('crimson romance', 1),
#  ('cross country cruise', 1),
#  ('cross streets', 1),
#  ('double door', 1),
#  ('the dover road', 1),
#  ('easy to love', 1),
#  ('eight girls in a boat', 1),
#  ('embarrassing moments', 1),
#  ...]

# %%
Counter(df["Plot"].apply(lambda x: x[:50])).most_common()
# Out:
# [('The plot revolves around the players on a hockey t', 4),
#  ('Jaihind is the journey of five people, linked by o', 3),
#  ('Hoppity the Grasshopper, after a period spent away', 2),
#  ('Eastern school teacher Catherine Allen becomes not', 2),
#  ('Captain Phillip Donlin (Lloyd Bridges) and his sma', 2),
#  ('Jack Flynn is driving down a highway at night, loo', 2),
#  ('Paul Winchell plays a father to Jerry Mahoney who ', 2),
#  ('Herbert H. Heebert (Jerry Lewis) is a young man wh', 2),
#  ('A 38-year-old writer of pornographic novels named ', 2),
#  ('In the fictional country of Lugash, a mysterious t', 2),
#  ('Following the grisly suicide of the U.S. Ambassado', 2),
#  ('By the end of the 19th century, Butch Cassidy, the', 2),
#  ('Bill Markham (Powers Boothe) is an engineer who ha', 2),
#  ('Ben White (Reb Brown) attends the funeral of his s', 2),
#  ('As noted above, Jackie Chan re-edited The Protecto', 2),
#  ('We see the origin of Pinhead as a British military', 2),
#  ('While on a routine patrol on United States airspac', 2),
#  ('Larry Wilson (Andrew McCarthy) and Richard Parker ', 2),
#  ('In the Pride Lands of Africa, a lion rules over th', 2),
#  ('The film takes place at an elite New England board', 2),
#  ("Greece's Ionian Islands are invaded by the Italian", 2),
#  ('In 1959, Lucinda Embry hears whispers while starin', 2),
#  ('Laurel and Audrey (Zoe Kazan) are identical twins.', 2),
#  ('Following a nuclear holocaust, the world has becom', 2),
#  ('In Akron, Ohio, 24-year-old Joy Newsome and her 5-', 2),
#  ('Joe Warr (Clive Owen) is a British sports writer w', 2),
#  ("Rabindranath Tagore's elder brother Jyotirindranat", 2),
#  ('Tanisha is a young daughter of a man working for t', 2),
#  ('Fanny (Phyllis Calvert) finishes at boarding schoo', 2),
#  ('Cremona, 1681 (Language: Italian)\r\nNicolò Bussotti', 2),
#  ('Half-witted longtime friends Albert (Luis Manzano)', 2),
#  ('The lives of three people take a turn when one of ', 2),
#  ('The Philippines, 1972. Mysterious things are happe', 2),
#  ('The film is set against the backdrop of unrest in ', 2),
#  ('Manohar moves into a new apartment, 13B, on the 13', 2),
#  ('A young boy named Rana, who hails from the kingdom', 2),
#  ('The film opens with an ancient Chinese mother and ', 2),
#  ('Some college students from Chennai go on vacation ', 2),
#  ('A student of Sacred Heart Medical College is found', 2),
#  ('The story revolves around a widowed father and son', 2),
#  ('This is the story of Venu, a middle class young ma', 2),
#  ('Pachamuthu (Parthipan) by his own confession is a ', 2),
#  ('The film opens with two people\xa0– a man (Aravind Ak', 2),
#  ('Sivaji, an Indian software architect, returns to I', 2),
#  ('Anbu (Vishal) is a happy-go-lucky engineering stud', 2),
#  ('Prabhu (Uday Kiran) is a college student who does ', 2),
#  ('The Plot opens with water over flowing from the Th', 2),
#  ('Ravi (Vijay), a youth from Thoothukudi, aspires to', 2),
#  ('Ashwin Kumar (Jiiva) is a photojournalist working ', 2),
#  ('Krishna (Vikram) is intellectually disabled and ha', 2),
#  ('The film starts in the 1980s. A young Shiva (Jiiva', 2),
#  ('The Scene begins in a Naxal infested area, where g', 2),
#  ("There was a bomb blast in People's Plaza at Hydera", 2),
#  ('Nayaki is a horror movie . Nayaki is about Gayathr', 2),
#  ('Sachin Joshi is a Kabaddi Player who loved a girl ', 2),
#  ('While vacationing, Koenma is kidnapped by a pair o', 2),
#  ('Hanamichi Sakuragi is a delinquent and the leader ', 2),
#  ('The film comes accompanied by a short mini-movie f', 2),
#  ('The background of the plot is based on the Stateme', 2),
#  ('In the fictional city of Mitakihara, Japan, a midd', 2),
#  ('Year 2157. Maxim Kammerer (Stepanov), a space expl', 2),
#  ('The film opens with two bandits breaking into a ra', 1),
#  ('The film is about a family who move to the suburbs', 1),
#  ('Before heading out to a baseball game at a nearby ', 1),
#  ('On a beautiful summer day a father and mother take', 1),
#  ('A thug accosts a girl as she leaves her workplace ', 1),
#  ('A young couple decides to elope after being caught', 1),
#  ('The film opens in a town on the Mexican border. A ', 1),
#  ('A rejected admirer sets up a trap to kill his swee', 1),
#  ('John Wharton, the husband of a true and trusting w', 1),
#  ('An old woman sends a girl begging in the streets o', 1),
#  ('Mary Pickford plays Priscilla an unemployed maid w', 1),
#  ('Hemlock Hoax is a detective who has little respect', 1),
#  ('During the American Civil War a young soldier lose', 1),
#  ('An Irish boy (Olcott) emigrates to America to esca', 1),
#  ('The novel is set in the reign of "old King Henry V', 1),
#  ("The story deals with Tom Brown's efforts to save h", 1),
#  ('Polly Biblett (Mary Pickford), a young lady, tells', 1),
#  ('The film is about a poor married couple living in ', 1),
#  ('Only lasting 15 minutes, it is a light-hearted com', 1),
#  ('The story is of an English manufacturing town {Hud', 1),
#  ('Barney Oldfield races a speeding locomotive to res', 1),
#  ('Bob, a typically devoted husband, is told by his w', 1),
#  ('Cohen (Ford Sterling) and his rival Goldberg (Henr', 1),
#  ('The setting is an early American village, where a ', 1),
#  ('The film begins with the Dreamer, a restless and d', 1),
#  ('A telephone operator is walking out with a handsom', 1),
#  ('In A Busy Day, a wife (played by an energetic Char', 1),
#  ("Graehme, Ned Stewart's father was accused of adult", 1),
#  ('Chaplin plays a waiter who fakes being a Greek Amb', 1),
#  ('The action starts in a park, where a man is trying', 1),
#  ('Chaplin plays a character quite different from the', 1),
#  ('The story involves Chaplin and Chester Conklin wor', 1),
#  ('The film begins with a short prologue explaining t', 1),
#  ('Mabel and her beau go to an auto race and are join', 1),
#  ('In one of Chaplin\'s "park comedies" for Keystone S', 1),
#  ('James Birch, an English hunter, is accidentally sh', 1),
#  ('Pug, a down-and-out hobo, is talked into pretendin', 1),
#  ('Charlie offers Mabel a ride on his two-seater moto', 1),
#  ("Mabel's Blunder tells the tale of a young woman wh", 1),
#  ('Chaplin, in tramp attire, sits in the park with hi', 1),
#  ('In a hotel lobby a heavily drunk tramp runs into a', 1),
#  ("Chaplin's character attempts to convince a passerb", 1),
#  ('The Masquerader is a comedy short whose plot revol', 1),
#  ('The hero, a janitor played by Chaplin, is fired fr', 1),
#  ('Charlie is in charge of stage "props" and has trou', 1),
#  ('Esra Kincaid (La Reno) takes land by force and, ha', 1),
#  ('A drunk reveller (Chaplin) returns home to a scold', 1),
#  ('Rough-and-tumble Gold Rush-era California: a woman', 1),
#  ('Grace Roberts (played by Lea Leland), marries ranc', 1),
#  ('The Masher played by Charlie Chaplin fights for th', 1),
#  ('Charles Chaplin portrays a womanizing city man who', 1),
#  ('Baron Yamaki (Sessue Hayakawa) is a fisherman who ', 1),
#  ('Ted Ewing (Edward Abeles) invests both his own and', 1),
#  ('Don José, an officer of the law, is seduced by the', 1),
#  ('Based on a summary in a film magazine,[2] Enoch, A', 1),
#  ('John Schuyler (Edward José), a rich Wall Street la', 1),
#  ('Considered a coward by his fiancée and comrades in', 1),
#  ('A farm youth goes to college, pursues the pretty c', 1),
#  ('Luke (Harold Lloyd) works in a shoe store, but has', 1),
#  ('Dora and her father are lost in the kitchen (they ', 1),
#  ('As described in a film magazine,[3] La Valencia (S', 1),
#  ('Mademoiselle Poppea (played by Glaum) is the leadi', 1),
#  ('As the American Civil War begins, Ned Burton leave', 1),
#  ('Charlie is an assistant to Izzy A. Wake, a painter', 1),
#  ('Dr. Edmund B. Stewart is a talented young physicia', 1),
#  ("The narrative hinges on Jason's vow to wreak venge", 1),
#  ('The film opens with the outbreak of a war in the p', 1),
#  ('A sultan agrees to help an evil witch destroy a my', 1),
#  ('Alicia is a poor girl living in the city with her ', 1),
#  ('Upon the death of her parents, little Hulda find h', 1),
#  ('Hoping to improve his financial lot, petty thief H', 1),
#  ('Robbers steal the "Koor-Hal Ruby", killing four in', 1),
#  ('Nadia, the daughter of a nobleman, rejects ancient', 1),
#  ('Mary Beresford (Boland) is the wife of unambitious', 1),
#  ('As described in a film magazine,[3] British noblem', 1),
#  ('The film is about a court case and embezzlement.', 1),
#  ('A father takes his daughter on a trip to Bermuda i', 1),
#  ('As described in a film magazine,[3] Cheyenne Harry', 1),
#  ('As described in a film magazine,[3] Armand Duval (', 1),
#  ('As described in a film magazine,[2] Noisy Jim (Cor', 1),
#  ('As described in a film magazine,[3] Silas Martin (', 1),
#  ('In a slum called Easy Street, the police are faili', 1),
#  ('The setting is the Old West town of Paradise, Neva', 1),
#  ('A young boy, Pip, runs into an escaped convict at ', 1),
#  ('Polly Biggs (Peggy Hyland) is the eldest of a fami', 1),
#  ('Arbuckle plays a drug store clerk, soda jerk, and ', 1),
#  ('The film begins aboard a steamer crossing the Atla', 1),
#  ('A young man drowns his sorrows in strong drink whe', 1),
#  ('As described in a film magazine,[4] Henri Labordie', 1),
#  ('As described in a film magazine,[5] Barbara Norton', 1),
#  ("The film opens with a sequence in which D'Artagnan", 1),
#  ('As described in Exhibitors Herald, a film magazine', 1),
#  ('As described in a film magazine review,[3] Neil Da', 1),
#  ('Gwendolyn is an 11-year-old girl who is left by he', 1),
#  ('As described in a film magazine,[3] Alexis Caesar ', 1),
#  ('As described in a film magazine,[4] Rebecca Randal', 1),
#  ("A philandering husband's public flirtation with a ", 1),
#  ('Early morning in the Rough family household and Mr', 1),
#  ('As described in a film magazine review,[3] Sebasti', 1),
#  ('At the end of the 19th century in the Far West, a ', 1),
#  ('Lola Montrose (played by Glaum) is a kept woman. T', 1),
#  ('As described in a film magazine,[2] Moctezuma (Hat', 1),
#  ('As described in a film magazine,[3] Susan Sweeney ', 1),
#  ('Set in San Francisco during the early 1900s, the f', 1),
#  ('Con artists Harold (Harold Lloyd) and Snub (Snub P', 1),
#  ('As described in a film magazine,[5] George MacFarl', 1),
#  ('As described in a film magazine,[3] believing he l', 1),
#  ("As described in a film magazine,[3] Cecilia's pare", 1),
#  ('Fatty is the head chef at the "Bull Pup" restauran', 1),
#  ('Carroll Wayles (Ford) is a chemist who has discove', 1),
#  ('As described in a film magazine,[3] Eleanor Hamlin', 1),
#  ('As described in a film magazine,[4] Joan (Murray),', 1),
#  ('The plot centers around an inter-racial romance be', 1),
#  ('A young girl suddenly finds herself wealthy, but l', 1),
#  ('The story is about a young woman who is a quarter ', 1),
#  ('As described in a film magazine,[2] the principle ', 1),
#  ('As described in a film magazine,[2] Bess Thurston ', 1),
#  ('As described in a film magazine,[2] determined to ', 1),
#  ('Set in the Virginia Hills, Fatty and Buster play r', 1),
#  ('Bebe plays a pretty young thing with several suito', 1),
#  ('As described in a film magazine,[4] disgusted by t', 1),
#  ('Arbuckle plays a drifter who has caught a ride hid', 1),
#  ('The film opens with flashbacks from Tarzan of the ', 1),
#  ('As described in a film magazine,[1] Salome uses he', 1),
#  ('As described in a film magazine,[2] "Kaintuck" Rid', 1),
#  ('After discovering that her grandmother was a gypsy', 1),
#  ('Charlie is in boot camp in the "awkward squad." On', 1),
#  ('Stella Maris (Mary Pickford) was born paralyzed an', 1),
#  ('John and Alice Clayton, Lord and Lady Greystoke (T', 1),
#  ('As described in a film magazine,[4] Yvonne (Vidor)', 1),
#  ('As described in a film magazine,[1] when Maria Val', 1),
#  ('As described in a film magazine,[1] very much in l', 1),
#  ('Nora, An actress (Enid Bennett) is performing in a', 1),
#  ('As described in a film magazine,[2] Doris Standish', 1),
#  ('As described in a film magazine,[2] John Tremble (', 1),
#  ('Lloyd is a serious young middle-class guy on the m', 1),
#  ('As described in a film magazine,[2] the plot of th', 1),
#  ('Barbara, a wealthy female socialite intent on refo', 1),
#  ('The film opens with a quick glimpse into the glamo', 1),
#  ('A police officer finds a baby in a trash can, and ', 1),
#  ('The film tells the story of an attempted Russian i', 1),
#  ('Based upon a description in a film magazine,[5] Le', 1),
#  ('Cabaret singer Olive Martin (played by Baird) appr', 1),
#  ('As described in a film magazine,[3] Blue Jean Bill', 1),
#  ('During World War I, a professional thief known as ', 1),
#  ('As described in a film magazine,[4] Dr. Edward Mea', 1),
#  ('A young woman stands to inherit a fortune, but a c', 1),
#  ('As described in a film magazine,[3] younger son Ja', 1),
#  ('A gang of men frame Harvey Hanford (Houdini) for m', 1),
#  ('As described in a film magazine,[2] ranch owner Ch', 1),
#  ('As described in a film magazine,[2] Jim Montjoy (M', 1),
#  ('As described in a film magazine,[3] New York repor', 1),
#  ('As described in a film magazine,[6] Anthony Hawtho', 1),
#  ('Jason Honeycutt (Harold Goodwin) is a young boy wh', 1),
#  ('As described in a film magazine,[4] Bill (Fairbank', 1),
#  ('As described in a film magazine,[3] Laura Dayne (B', 1),
#  ('The film centers on the relationship between Lady ', 1),
#  ('As described in a film magazine,[4] wealthy clubma', 1),
#  ('As described in a film magazine,[5] Clive (Standin', 1),
#  ('A young man (Fay) goes out to eat breakfeast with ', 1),
#  ('As described in a film magazine,[5] novelest Harri', 1),
#  ('According to a contemporary New York Times article', 1),
#  ('As described in a film magazine,[3] "Toodles" Wald', 1),
#  ('As described in a film magazine,[3] the senior Joh', 1),
#  ('As described in a film magazine,[5] Rosie Nell (Be', 1),
#  ('Based upon a plot summary included in a film revie', 1),
#  ('Robert Clay, a noble America hero of humble means ', 1),
#  ('Charlie works on a farm from 4 a.m. to late at nig', 1),
#  ('Martin Wingrave(Barrymore) is arrested and sent to', 1),
#  ('As described in a film magazine,[2] "True Heart Su', 1),
#  ('As described in a film magazine,[2] Paul Perry (Hu', 1),
#  ('As described in a film magazine,[2] Gudrun Trygavs', 1),
#  ('As described in a film magazine,[3] Dick Armitage ', 1),
#  ('Based upon a plot summary in a newspaper,[3] Amy (', 1),
#  ('As described in a film magazine,[3] Daniel Boone B', 1),
#  ('As described in a film magazine,[4] Lord Angus Cam', 1),
#  ('As described in an adaptation of the film in the O', 1),
#  ('Captain Bob White, an American aviator behind enem', 1),
#  ('As described in a film magazine,[2] old Gordon Rog', 1),
#  ('As described in a film magazine,[3] April Poole (D', 1),
#  ('As described in a film magazine,[2] when Elizabeth', 1),
#  ('Charles Stoddard (played by Hale) is a poor artist', 1),
#  ('Buster, a particularly untalented golfer plays gol', 1),
#  ('As described in a film magazine,[9] Grace Goodrigh', 1),
#  ('As described in a film publication,[4] Betty Palme', 1),
#  ('As described in a film publication,[4] the proud, ', 1),
#  ('As summarized in a film publication,[2] Laurie Dev', 1),
#  ('As described in a film magazine,[3] Rex Rossmore (', 1),
#  ('The action in Haunted Spooks centres around Harold', 1),
#  ('As described in a film magazine,[4] Princeton Hadl', 1),
#  ('The film revolves around a young woman who sleepwa', 1),
#  ('As described in a film publication,[2] Huckleberry', 1),
#  ('Mary (Seymour) is the daughter of a French man and', 1),
#  ('As described in a film magazine,[3] in a small tow', 1),
#  ('As described in a film magazine,[2] Peter Lane (Tu', 1),
#  ('As described in a film magazine,[1] Judy (Minter),', 1),
#  ('As described in a film magazine,[3] granddaughter ', 1),
#  ('A young woman, Natalie Storm (played by Glaum), wo', 1),
#  ('As described in a film magazine,[4] Thomas Bevan (', 1),
#  ('While at an amusement park, trying vainly to forge', 1),
#  ('The film opens in the Ozarks where a distraught Po', 1),
#  ('As described in film publications,[2][3] Janie (Gi', 1),
#  ('As described in a film publication,[2] a youth (Ar', 1),
#  ('As described in a film magazine,[3] it is his love', 1),
#  ('Nicholas Van Alstyne is the richest man in New Yor', 1),
#  ('The film is a morality story on the evils of marit', 1),
#  ('A period newspaper gives the following description', 1),
#  ('As summarized in a film publication,[5] Marjorie B', 1),
#  ('As described in a film magazine,[4] Deane Kendall ', 1),
#  ('As described in a film magazine,[2] Princess Kalor', 1),
#  ("As described in a film magazine,[4] David Markely'", 1),
#  ('The main charter Karl Breitman played by Henry B. ', 1),
#  ('Amanda Afflick (Mary Pickford) is a poor laundry w', 1),
#  ('Based upon a review in a film publication,[2] Sari', 1),
#  ('Frumpy wife Beth devotes herself to bettering her ', 1),
#  ('The film opens with Sylvia Landry (Evelyn Preer), ', 1),
#  ("As described in a film magazine,[4] Mary's (Bennet", 1),
#  ('Socialite Anatol Spencer (Reid), finding his relat', 1),
#  ("Mrs. O'Brien (Herring) is eager to be accepted as ", 1),
#  ('As summarized in a film publication,[2] Buck (Jone', 1),
#  ('At the end of class, poorly paid college professor', 1),
#  ('Buster is married with two children (both of whom ', 1),
#  ('The plot of Experience was summarized in the Augus', 1),
#  ('Mrs. Mallory (Williams) persuades Mary Maddock (Ay', 1),
#  ('Peter Ibbetson (Reid) is an orphan raised by his u', 1),
#  ('Madariaga "The Centaur" (Pomeroy Cannon), a harsh ', 1),
#  ('Buster Keaton is walking by and peers through a ba', 1),
#  ('Keaton plays a teller at a successful bank. Unbekn', 1),
#  ('As described in a film publication,[3] idealistic ', 1),
#  ('The Boy meets and marries The Girl. A year later, ', 1),
#  ('As described in a film magazine,[3] raised aboard ', 1),
#  ('Based upon a summary in a film publication,[2] Ang', 1),
#  ('As described in a film magazine,[3] John Trott (Hu', 1),
#  ('A hapless hero (Laurel), who after being thrown ou', 1),
#  ('As described in a film publication,[5] several yea', 1),
#  ('Harold works in an office on a tall building next ', 1),
#  ('As described in a film magazine,[3] the Brandeis o', 1),
#  ('Based upon a summary in a film publication,[4] Cha', 1),
#  ('Just before the French Revolution, Henriette takes', 1),
#  ('The film is set up as a series of humorous tricks ', 1),
#  ('As summarized in a film publication,[3] David Mars', 1),
#  ('"The Boy" (Lloyd) is an idle playboy and heir to $', 1),
#  ('Captain John Nelson (Hobart Bosworth) and his crew', 1),
#  ('Max Linder returns home drunk after his bachelor p', 1),
#  ('As described in a film publication,[4] the story i', 1),
#  ('While discussing heredity, a man recalls the story', 1),
#  ('The Sky Pilot (Bowers) arrives in a small rough-an', 1),
#  ('As described in a film magazine,[2] easy going ran', 1),
#  ('David Kinemon, youngest son of West Virginia tenan', 1),
#  ('As described in a film magazine,[3] after her drun', 1),
#  ('As described in a film magazine,[4] Josephine Gers', 1),
#  ('Captain Fitzgerald (Alec B. Francis), a retired gu', 1),
#  ('The film is a contemporary (1920s, though the book', 1),
#  ('Buster wants to marry a girl, but her father disap', 1),
#  ('The Sick-Little-Well-Girl (played by Mildred Davis', 1),
#  ('An Indian maid and American girl (both played by F', 1),
#  ('Keaton plays a botany student who is accidentally ', 1),
#  ('In Sicily, Count Martinello is assassinated by Car', 1),
#  ('The silent drama tells the story of a man who name', 1),
#  ('As described in a studio publication,[2] Bert Lyon', 1),
#  ('The opening scenes are set in Scandinavia, where a', 1),
#  ('Chaplin plays a laborer on a house construction si', 1),
#  ('As described in a film magazine,[3] the board of d', 1),
#  ('As described in a film publication,[3] Margaret "P', 1),
#  ('Based upon a review in a film publication,[2] Cyri', 1),
#  ('Leon de Severac is fed up with his daughter Jacque', 1),
#  ('Spoiled son Andrew Kane (Joseph Striker) competes ', 1),
#  ("As reviewed in a film magazine,[3] a rich man's so", 1),
#  ('After fifteen years, Joshua Judd (Charles Ogle) te', 1),
#  ('Ambrose Applejohn is bored with his life in Cornwa', 1),
#  ('At the ball celebrating the wedding of Henry of Na', 1),
#  ('A young man (Keaton) has a series of encounters in', 1),
#  ('Lee Clavering (Tearle), a playwright in New York, ', 1),
#  ('Glenn Kilbourne (Richard Dix) returns from the war', 1),
#  ('A university student named John Browning (Charles ', 1),
#  ('Sue Graham (Normand) is a small town girl who trav', 1),
#  ('Julia (Bessie Love) is a "small-town heartbreaker"', 1),
#  ('The Canfield and McKay families have been feuding ', 1),
#  ('The Pilgrim (Chaplin), an escaped convict, steals ', 1),
#  ('The film opens in 1922 with Harold Lloyd (the char', 1),
#  ('In 1906, Wilse Dilling (Lon Chaney), a crippled ga', 1),
#  ('The film is a spoof of Rudolph Valentino’s hit 192', 1),
#  ('Benadict Hisston is a foreign agent, part of a con', 1),
#  ('The title is also the moniker of a renowned safe-c', 1),
#  ('Remember "Mem" Steddon (Eleanor Boardman) marries ', 1),
#  ('Three plots in three different historical periods—', 1),
#  ('Harold Van Pelham (Lloyd) is a rich businessman wh', 1),
#  ('Jamil (Ramon Novarro) is a soldier in the Bedouin ', 1),
#  ('Cecilie Brunner (Murray) was once a good natured w', 1),
#  ('Crippled by the war, Oliver Bashforth (Richard Bar', 1),
#  ('Kerry Harlan (La Rocque) is unable to work because', 1),
#  ('John McTeague is a miner working in Placer County,', 1),
#  ('Paul Beaumont (Lon Chaney) is a scientist who labo', 1),
#  ('Toodie and Budge are identified as the two best ch', 1),
#  ('American millionaire Samuel C. Adams brings his da', 1),
#  ('Gritzko (John Gilbert) is a Russian nobleman and T', 1),
#  ('Episodic in nature (effectively three short films ', 1),
#  ('The film presents an idealized image of the constr', 1),
#  ('A family from Poland has been left homeless in the', 1),
#  ('The shop girl Tessie McGuire is invited by her bos', 1),
#  ('The Duke of Chartres is in love with Princess Henr', 1),
#  ('Wealthy Rollo Treadway (Buster Keaton) suddenly de', 1),
#  ("Madame L'Enigme (Laurette Taylor) is a fortune-tel", 1),
#  ('Jean Leonnec (Ramon Novarro) and Marise La Noue (E', 1),
#  ('In Renaissance Florence, a Florentine trader meets', 1),
#  ('A movie theater projectionist and janitor (Buster ', 1),
#  ('A dancer known as Lou Lorraine feels her life is g', 1),
#  ('John Woolfolk and his wife are riding down a count', 1),
#  ('Through a series of confusions, Dudley Ainsworth (', 1),
#  ('In the United States in 1917, James "Jim" Apperson', 1),
#  ('Matrimony is not only a good thing, but also a goo', 1),
#  ('The King of Illyris (Lewis Stone) marries a neighb', 1),
#  ('During the First World War Captain Alan Trent - on', 1),
#  ('American millionaire Frederick Harmon (played by L', 1),
#  ('Although he wins the championship by a knockout, p', 1),
#  ('The plot concerns Beaumont, a horse breeder with a', 1),
#  ('A young woman marries the wastrel son of a British', 1),
#  ('In London, Lady Margaret Windermere is busy discou', 1),
#  ('Annie Rooney is a young girl who spends her days w', 1),
#  ('Following the death of the owner of the Hunt ranch', 1),
#  ('Cathleen Gillis (May McAvoy) falls in love with Ja', 1),
#  ('Zara (Aileen Pringle) is a gypsy rogue who joins w', 1),
#  ('Tim Kelly (Jackie Coogan) and Max Ginsberg (Max Da', 1),
#  ('The film opens with the debut of the new season at', 1),
#  ('Tim Kelly (Jackie Coogan) is a kid who runs away f', 1),
#  ('The film takes a behind-the-scenes look at the rom', 1),
#  ('Because she married a circus performer, Judge Fost', 1),
#  ('The film opens with a foreword:\r\nThe story begins ', 1),
#  ('Jimmy Shannon (Buster Keaton) is the junior partne', 1),
#  ('At 40, businesswoman Jane Vale (Pauline Frederick)', 1),
#  ('Jennie Hagan (Swanson) is a waitress who dreams of', 1),
#  ('Singer Nora (Mae Busch) left her husband for new f', 1),
#  ('Richard Gaylor Jr. (Richard Dix) is a modern Lotha', 1),
#  ('Jan (Lon Chaney) is a Swedish farmer and Glory (No', 1),
#  ('Tex Hartwell (Buck Jones) rescues an old cobbler f', 1),
#  ('Dick Bannister is the new field boss of the Ford L', 1),
#  ("Alfred's father wants him to make a man of himself", 1),
#  ('Old Bill (Sydney Chaplin), a jovial Limey sergeant', 1),
#  ('Beverly Calhoun (Davies) impersonates the Prince o', 1),
#  ('The Blackbird (Lon Chaney) is a thief who uses a s', 1),
#  ('Several struggling bohemians try to survive in the', 1),
#  ('Comedy about a small-town girl unhappy with her fa', 1),
#  ("The film stars actor Rod La Rocque as 'Jerry Clegg", 1),
#  ('May (Claire Windsor) is married to Roger (Conrad N', 1),
#  ("In the prologue, Don José, warned of his wife's in", 1),
#  ('In the house of late father, Ella Cinders (Colleen', 1),
#  ('The film concerns a rich young Frenchman (Conrad N', 1),
#  ('Burlesque chorus girl Orchid Murphy (Gloria Swanso', 1),
#  ('The film is a romantic melodrama[1] about two chil', 1),
#  ('Millionaire J. Harold Manners (Harold Lloyd) finds', 1),
#  ('A deceiver leads the fast set in Paris and is invo', 1),
#  ('Western & Atlantic Railroad train engineer Johnnie', 1),
#  ('Following a series of robberies of the K & A Railr', 1),
#  ('The film tells the story of Jack, a spy for the Co', 1),
#  ('Julian Perryam (Lloyd Hughes) gets thrown out of O', 1),
#  ('Jewel Courage (Borden) rejects a suitor (Hamilton)', 1),
#  ('After a bully helps him out of a jam, Samuel "Kid"', 1),
#  ('A telephone line repairman named Joe Graham (Spenc', 1),
#  ('In the Latin Quarter of Paris, sculptor Margaret D', 1),
#  ('As a young boy growing up in a Spanish family with', 1),
#  ('Polly Brewster (Daniels), a penniless Hollywood ex', 1),
#  ('Early in the 19th century, the USS Constitution is', 1),
#  ('Isadore Goldberg, an enterprising Russian Jew, com', 1),
#  ('At the beginning of the story, Ahab (John Barrymor', 1),
#  ('Paul Giraud is happily married to Suzanna, and tog', 1),
#  ('Sam Bisbee (W.C. Fields) is a small-town glazier w', 1),
#  ('Paul Bergot (Harry Langdon) is a Belgian immigrant', 1),
#  ('The story opens in Paris at a masquerade ball wher', 1),
#  ('The wealthy matriarch Doña Bernarda Brull (Mattox)', 1),
#  ("The film tells of Harry (Langdon) a ne'er-do-well ", 1),
#  ('As a child, Barbara is orphaned when her settler p', 1),
#  ('"The little fur-bearing animals that are sacrifice', 1),
#  ('Jean Waddington (Esther Ralston) and Ted Larrabee ', 1),
#  ('Newlywed Carl (Ralph Forbes) goes to war where he ', 1),
#  ('Marion Bright enrolls in college to pursue a hands', 1),
#  ("A baby boy is found abandoned in a Hell's Kitchen ", 1),
#  ('Captain Robert Kelly (McCoy) while attached to the', 1),
#  ('Father Adrien (Iván Petrovich), a monk at the Trap', 1),
#  ('The story tells of Harry Howells (Langdon), a rece', 1),
#  ('The Hickorys are a respected family in Hickoryvill', 1),
#  ('When a successful prizefighter known as "Killer" A', 1),
#  ('A girl travelling by train to meet her boyfriend m', 1),
#  ('In a cultured and peaceful home on the outskirts o', 1),
#  ('The silent tells the story of Harry Shelby (Langdo', 1),
#  ('The film depicts a young woman (Swanson) granted t', 1),
#  ('Tina (Marion Davies) is the drudge of the Red Mill', 1),
#  ('Katyusha, a country girl, is seduced and abandoned', 1),
#  ('Serafina (Marceline Day) is captured by Don Baltha', 1),
#  ('During World War I an entertainer named Greg Lee (', 1),
#  ('Cock Robin (John Gilbert) is a sideshow barker in ', 1),
#  ('A vacationing Woman from the City (Margaret Living', 1),
#  ('In the story, which opens in the early 1900s, Jann', 1),
#  ('The film starts with the loading of a ship called ', 1),
#  ('Jack Powell and David Armstrong are rivals in the ', 1),
#  ('Captain Winslow takes a revolutionary new clipper ', 1),
#  ('The plot concerns four orphans (Janet Gaynor, Nanc', 1),
#  ('Two young men, "Speed" Doolittle (Arthur Lake) and', 1),
#  ('The film tells the story of a woman (Dorothy Macka', 1),
#  ('A young doctor (William Collier Jr) is accused by ', 1),
#  ('A group of American coeds/flappers arrives at the ', 1),
#  ('The story takes place in old Mexico, where a maske', 1),
#  ('The story centers on an Asian woman named Onoto (L', 1),
#  ('Born on the Fourth of July, 1900, John Sims (James', 1),
#  ('Marianne (Greta Garbo) is a poor French country gi', 1),
#  ('An American tramp steamer docks in New York harbor', 1),
#  ('A flapper masquerades as her straight-laced cousin', 1),
#  ('In Sussex, England after the Great War, former ari', 1),
#  ('After finding out her father and his estate is in ', 1),
#  ('Wealthy divorced American Willoughby Quimby has be', 1),
#  ('Set in the fictitious European kingdom of Balanca,', 1),
#  ('Mother Bernle is a widow in Bavaria with four sons', 1),
#  ('Benny Horowitz (John Gilbert), a reformed gangster', 1),
#  ('A Viennese ingénue named Toni LeBrun, (Corinne Gri', 1),
#  ('The film is a semi-historical narrative and depict', 1),
#  ('This drama features a romance between two differen', 1),
#  ('Patience Winslow (Esther Ralston) is an impulsive ', 1),
#  ('A young man tries to enlist in the United States A', 1),
#  ('Dolly "Angel Face" Morgan is a parolee out to flee', 1),
#  ('In 1928 Hollywood, director Leo Andreyev (William ', 1),
#  ('Tito (Lon Chaney), a traveling circus clown, finds', 1),
#  ('Betty Dallas (Crawford) is a passenger on a stagec', 1),
#  ('In World War I, four young men from various walks ', 1),
#  ('Seven young English aviators are billeted at the B', 1),
#  ('Judge Ross, on the Federal Bench, rules in favor o', 1),
#  ('Hannerl (Philbin) is a young woman growing up in O', 1),
#  ("Count D'Estrange tries to save his nephew Hubert f", 1),
#  ("In 1690's England, King James II sentences his pol", 1),
#  ('Don Wilson, a famous blackface comedian, is prepar', 1),
#  ('Leslie Hatton, a poor farmer, becomes a captain an', 1),
#  ('Fannie Brand (Fanny Brice), an industrious girl wh', 1),
#  ('Rosalind McGill (White) is a cloak room girl falls', 1),
#  ('The film opens after the great flood, with Noah an', 1),
#  ('A man is put on trial for the murder on his best f', 1),
#  ('"Dangerous Diana" Medford (Crawford) is outwardly ', 1),
#  ('Tasia (Dolores del Río), a beautiful dancer lower ', 1),
#  ('A free-spirited young girl has three middle-aged a', 1),
#  ('A smoking, drinking, jazz listening, young prostit', 1),
#  ('Doug Caswell (Arthur Rankin) falls for Irene Gordo', 1),
#  ("George (George O'Brien) is a sailor and smooth-tal", 1),
#  ('Dixie Dugan, a Brooklyn cutie, goes to the offices', 1),
#  ('Young Peggy Pepper (Marion Davies) wants to be in ', 1),
#  ('After years of hopeful struggle, Al Stone (Jolson)', 1),
#  ('A self-centered polo player (Haines) has to redeem', 1),
#  ('Jerry McGuire (William Collier Jr.) is a dress des', 1),
#  ('Everybody in New York City "is in such a hurry tha', 1),
#  ('William "Steamboat Bill" Canfield is the owner and', 1),
#  ('The young brother of two police officers borrows o', 1),
#  ('A spirited young woman (Gaynor) tries to steal mon', 1),
#  ('Molly Kelly (Viola Dana) intends to marry a millio', 1),
#  ('The Boys (Stan and Oliver) are trying to attend a ', 1),
#  ('In Vienna in 1914, Prince Nicki is the scion of a ', 1),
#  ('Anna (Jacqueline Gadsden) cannot bring herself to ', 1),
#  ('Arrogant and wise-cracking Brice Wayne (William Ha', 1),
#  ('Louis Hozenozzle and 2d Lieut. Rodney Ramsbottom, ', 1),
#  ('An impoverished young woman named Letty Mason (Lil', 1),
#  ('Diana Merrick (Greta Garbo), Neville (John Gilbert', 1),
#  ('Marian is sent to prison for a crime she did not c', 1),
#  ('Brooks (William Norton Bailey), a publisher and hi', 1),
#  ('The scene opens where the passenger train, hauled ', 1),
#  ('Lash is the head coal stoker on a steam ship whose', 1),
#  ('In the French colony of Cochin-China, young French', 1),
#  ('In turn-of-the-century Vienna, simple peasant girl', 1),
#  ('A spoiled rich girl falls for a poor chauffeur. Th', 1),
#  ('Norma Besant, daughter of a Southern doctor, is an', 1),
#  ('A gang of thieves rob an African diamond company o', 1),
#  ("In 1874, Disraeli's ambitious foreign policy, aime", 1),
#  ('Young David Carroll takes over the publication of ', 1),
#  ('Coal miner Hagon Derk (Charles Bickford) is senten', 1),
#  ('Naomi Iverson learns that her father has assumed t', 1),
#  ('Tired of being hit and hurt, football star Marty R', 1),
#  ('Jason Robards Sr. (Carvel Emerson) and George Fawc', 1),
#  ('Stephen Ghent, a mineowner, falls in love with Rut', 1),
#  ('Judy Page is a young society girl who falls in lov', 1),
#  ('Sharecroppers Zeke and Spunk Johnson sell their fa', 1),
#  ('A Southern belle (Loy) must work in a gambling hou', 1),
#  ('Although being engaged against her will with a wea', 1),
#  ('A poor songwriter from the south, Barry Holmes, tr', 1),
#  ('Disgusted that his fiancee, Diane (Jetta Goudal) h', 1),
#  ("Bored and lonely living on her husband's rubber pl", 1),
#  ('Ann Carter, an inexperienced young woman, accepts ', 1),
#  ('Set on the Maine coast, a young sloop skipper Bram', 1),
#  ('Saddled with the care of a younger brother and una', 1),
#  ('Bobby Murray is the middleweight champion, managed', 1),
#  ('A wealthy man dresses up as Napoleon for a fancy d', 1),
#  ('Heiress Billie Brown (Crawford), is engaged to mar', 1),
#  ('Trader Henry Slater (Donald Crisp) stops at a Sout', 1),
#  ('Prince Wolfram (Byron) is the betrothed of mad Que', 1),
#  ('After attending preparatory school and college in ', 1),
#  ('Allen John Spender (Charles Farrell) is a virile o', 1),
#  ('A common convention in the early decades of newspa', 1),
#  ('Jim and Eve, a young society couple, are kidnapped', 1),
#  ('The eighteen-year-old Magnolia meets, falls in lov', 1),
#  ('World War I British aviator Jack Bardell (John Gar', 1),
#  ('Cowboy Jack "Dirty Neck" Purvin travels to San Fra', 1),
#  ("Rory O'More leaves his sweetheart Kathleen O'Conno", 1),
#  ('Elmer, a humble worker in a dry cleaning establish', 1),
#  ('In Hungary, a beautiful, young gypsy girl, Nubi, s', 1),
#  ('James Rutherford has organized an expedition to th', 1),
#  ('The Four Seasons are a very good jazz quartet, but', 1),
#  ('Famed playwright Donald Anthony returns home to Ma', 1),
#  ('Vilma Banky portrays a newly arrived Hungarian imm', 1),
#  ('A humble woman (Swanson) marries a wealthy man (Am', 1),
#  ('In pre-European New Zealand there are two hostile ', 1),
#  ('The credits (accompanied by organ music endemic to', 1),
#  ('Alan Camp has written a book on eugenics, and is l', 1),
#  ('Eve Quinn, a shallow but attractive debutante, mak', 1),
#  ('Harold Bledsoe, a student of botany, is traveling ', 1),
#  ('Tiger Haynes traps wild animals for a living, and ', 1),
#  ('Peabody Jr. (Neil Hamilton) and his friends prepar', 1),
#  ('John Sterling (Lewis Stone) takes his young wife L', 1),
#  ('Sam Lash (Gary Cooper) is a fur trapper with a ran', 1),
#  ('Dan, a tough police captain, and Ray, a hardened c', 1),
#  ('The child of Jewish immigrants, Morris Goldfish (R', 1),
#  ("The first act of the film covers Lincoln's early l", 1),
#  ('A newspaper headline explains that society matron ', 1),
#  ('Anna Christie is the story of a former prostitute ', 1),
#  ('Montero is a bandit who, along with his deaf-mute ', 1),
#  ('Gardoni, a down-on-his-luck vaudeville performer, ', 1),
#  ('A ruthless, crooked stockbroker is murdered at his', 1),
#  ('Kent (Robert Montgomery), a drunk driver who carel', 1),
#  ('A large caravan of settlers attempt to cross the O', 1),
#  ('Peter Foley (Rex Lease) is a beneficiary of his gr', 1),
#  ('Ian Keith plays a French military attaché in Madri', 1),
#  ('Sergeant Grischa Paprotkin of the Imperial Russian', 1),
#  ('Amos and Andy run the "Fresh Air Taxicab Company, ', 1),
#  ('Bennett plays Mary Colbrook, the widowed mother of', 1),
#  ('After selling his house and belongings in East Afr', 1),
#  ('A golddigger marries a young man for his money, bu', 1),
#  ('Ted (Chester Morris), Jerry (Norma Shearer), Paul ', 1),
#  ('Elmer (Keaton), a member of the idle rich, is smit', 1),
#  ('In a small town in Virginia, Barbara Kent, is bein', 1),
#  ('Alice Kendall is the darling of her social set, th', 1),
#  ('When Johnny Quinlan loses his job in a drug store,', 1),
#  ('Harold Horne, an ambitious shoe salesman in Honolu', 1),
#  ('A chorus girl gets bad advice from her fellow chor', 1),
#  ('In New York City, William Foster (William Powell) ', 1),
#  ('The film takes place in the 18th century Austria a', 1),
#  ('Jim, a British Lord, suffers from pyrophobia, a fe', 1),
#  ('Tom Ward, a cocky young football hero, returns hom', 1),
#  ('A small plane carrying three British citizens — Ma', 1),
#  ('The titular character is a temperamental but lovab', 1),
#  ('During World War I, two American Doughboys, Tommy ', 1),
#  ('Geoffrey Clarke is a poor poet, who has his eyes o', 1),
#  ('Anita Morgan, a descendant of the famous pirate He', 1),
#  ('Four men, Bob Sangster, "Barbwire" Gibbons, "Wild ', 1),
#  ('A bootlegger in trouble with the law hides out on ', 1),
#  ('Looloo (Walker) runs a diner which is frequented w', 1),
#  ('Two fast-talking insurance salesmen — Wilbur Boswe', 1),
#  ('Jim Dolan, with a little help from his grandmother', 1),
#  ('Monte Blue, a young miner, manages to escape from ', 1),
#  ('On the eve of a battle in 1918, a new officer, Sec', 1),
#  ('A man is left by his wife and assuming her to be g', 1),
#  ('Tony, a prosperous Italian vineyardist in Californ', 1),
#  ('When Francisco Delfino (Richard Barthelmess) goes ', 1),
#  ('Peggy is a Follies dancer who forsakes her life of', 1),
#  ("When Marion Corsey's husband, Andrew, is conned ou", 1),
#  ('Peter Darby is an electrician sent on a call to th', 1),
#  ('Socialite Angela Brooks (Kay Johnson) discovers th', 1),
#  ('The film takes place in Neu Posen, German East Afr', 1),
#  ('The trouble begins when Lord Strathpeffer (John Ba', 1),
#  ('After the United States enters World War I in 1917', 1),
#  ('Lady Jane Winston (Lane), heiress to a company cal', 1),
#  ('Leopold Trebel (Frank Fay) is a man who was in a t', 1),
#  ('Joan Prescott (Joan Crawford) is a vacuous and fli', 1),
#  ('The film is set in the late 1920s. It opens in Mor', 1),
#  ('The film is focused on the life of widowed mother ', 1),
#  ('Rancher Tug Wilson (Alfred Hewston) discovers his ', 1),
#  ('Publisher Larry Fellowes (Lewis Stone) believes th', 1),
#  ('An American newspaper reporter named Charlie Carro', 1),
#  ('An outlaw on the run is hidden by the foreman of a', 1),
#  ('Putting a son through college, Julianne, owner of ', 1),
#  ('Susie (Helen Ware), who runs a house for gangsters', 1),
#  ('The story takes place in a small town in Georgia. ', 1),
#  ('Fellow department store shopgirls and roommates Ge', 1),
#  ('Robinson plays the ruthless boss of a criminal gan', 1),
#  ('Henry and Ann, a pair of young lovers, are plannin', 1),
#  ("Jim Murdock's marriage is in trouble after he negl", 1),
#  ('Gene Fenmore is a suave gentleman, safely ensconce', 1),
#  ('Alice White plays the part of a working class girl', 1),
#  ('In remote northern Canada, Sergeant Conniston (Bic', 1),
#  ('Loretta Young plays the part of an orphan who has ', 1),
#  ("On New Year's Eve, Harry (Elliott Nugent) tells hi", 1),
#  ('Working as lumberjacks in the Northwest, Billy Wes', 1),
#  ('The film begins with a parked car with drawn curta', 1),
#  ('Mary Gray (Mary Astor) and Dick Mercer (David Newe', 1),
#  ('When Littleton Looney, a crane driver, inherits $1', 1),
#  ('After years of abusing his Austrian immigrant wife', 1),
#  ('Pink Barker (Arlen) loses his boat and his girl Da', 1),
#  ('Vallery Grove (Costello) is in love with Don Warre', 1),
#  ('Not long after the death of his first wife, Walter', 1),
#  ('Tommy Mills wants to marry his girlfriend, Marie T', 1),
#  ('In the Alaska wilderness, Boyd Emerson and Fraser,', 1),
#  ('Sylvia Brenner (Constance Bennett) is a plain secr', 1),
#  ('Marco Perkins (Oakie) is a garage mechanic and a w', 1),
#  ('Sam Lee (Barthelmess) is the only son of extremely', 1),
#  ('Ted Healy is a salesman for the Schmidt Costume Sh', 1),
#  ('John Marsden, a famed and powerful New York gamble', 1),
#  ('Elinor, encouraged by her ambitious sister, reluct', 1),
#  ('When the film begins we find Alice White stranded ', 1),
#  ('A young bandit called the Llano Kid (Gary Cooper) ', 1),
#  ('While on holiday in a small French town, an Englis', 1),
#  ('After arguing with his sweetheart, Becky Thatcher,', 1),
#  ('Eddie Haskins (Lease), a wisecracking young man, t', 1),
#  ("Billy Bear (Fairbanks) is a broker's clerk who has", 1),
#  ('Lee Joyce tells her lover, Howard LeMoyne, that sh', 1),
#  ('Unassertive bookkeeper Simon Haldane (Horton) is t', 1),
#  ('Lieutenant Robert Banks (Buddy Rogers), a young Am', 1),
#  ('Jealousy comes between a young couple of newspaper', 1),
#  ('At an evening party in New York City, the Towners ', 1),
#  ("The story depicts Hamilton's (George Arliss) effor", 1),
#  ('Bill Harper (Rogers) plays an American ambassador.', 1),
#  ('After they are separated shortly after their marri', 1),
#  ('Eddie Brand (Eric Linden) is a high school student', 1),
#  ('An idealistic young medical student named Martin A', 1),
#  ('In 1849, Joaquin Murietta (Buck Jones) is determin', 1),
#  ('Wayne Carter is a New York playboy, who pays no at', 1),
#  ('Ageing English bachelor Sir Basil Winterton (C. Au', 1),
#  ('Dorothy Haley (Sally Eilers) and Edna Driggs (Minn', 1),
#  ('Naive Marianne Madison, bored with her routine lif', 1),
#  ('The last two surviving members of a French Foreign', 1),
#  ('Mary Linden (Mary Astor) is a receptionist at a pa', 1),
#  ('On the Western Front during World War I, an Americ', 1),
#  ('A rash go-getter is duped by would-be swindlers in', 1),
#  ('Bert Harris works for a hotel as a bellboy. One da', 1),
#  ('In World War I, American pilots Mal Andrews (Charl', 1),
#  ('Captain Wilks (F.R. Smith) of the Texas Rangers or', 1),
#  ('Doris Kendall (Constance Bennett) is an American n', 1),
#  ('Raised in poverty by a never-married mother, Steph', 1),
#  ('Brown plays Ossie, a New York City playboy sent to', 1),
#  ('Ambrose Applejohn lives in an extravagant old mans', 1),
#  ('Madelynne Cabrone is the wife of gangster Joe Cabr', 1),
#  ('Tommy Tanner (Wheeler) and Egbert G. Higginbotham ', 1),
#  ('During World War I, Jack (Douglas Fairbanks Jr.) a', 1),
#  ('Valerie West is a young American expatriate living', 1),
#  ('The intimate diary of Patricia Harper tells the st', 1),
#  ('In prohibition-era Manhattan, shopkeeper Mary Brow', 1),
#  ('Wendell Graham (Bert Wheeler), while a millionaire', 1),
#  ('Princess Ling Moy lives next door to the Petrie fa', 1),
#  ('Shirley Mortimer (Ann Harding) is the second daugh', 1),
#  ('When the famed explorer Louis Rondelle (Hobart Bos', 1),
#  ('On a whim, Herbert Blake proposes a wager with Rog', 1),
#  ('Growing up in a poor working-class family, Laura (', 1),
#  ('The trophy wife of a stodgy man of wealth yearns f', 1),
#  ('Linda Randolph (Hobart) looks for her husband on t', 1),
#  ('Dr. J. Dockweiler Droop (Robert Woolsey) is a carn', 1),
#  ('In a heavy rainy night 2 couples -Dr. Ed Marcy, Ti', 1),
#  ('Clint Belmet (Gary Cooper) is a bit of a firebrand', 1),
#  ('Tim Benton (Tim McCoy) is falsely accused of killi', 1),
#  ('Joseph W. Randall, the city editor of a tabloid ne', 1),
#  ('Waitress Pansy Botts (Charlotte Greenwood) places ', 1),
#  ('Defense lawyer Stephen Ashe (Lionel Barrymore) suc', 1),
#  ('John Macy runs a wagon train caravan which supplie', 1),
#  ('British Army captain Geoff Roberts (Adolphe Menjou', 1),
#  ('The film, considered a screwball comedy, centers o', 1),
#  ('Jack Thomas has grown up in the belief that he was', 1),
#  ('Wanda Howard (Kay Francis) and Marie Bailey (Lilya', 1),
#  ('In every port, sailor Bill, Spencer Tracy, meets g', 1),
#  ('While docked in a Caribbean port aboard a third-ra', 1),
#  ("Polo player Tony Bard (George O'Brien) travels Wes", 1),
#  ('Wall Street trader Jerry Stafford (Fredric March) ', 1),
#  ('A widowed fisherman (Huston) falls in love with an', 1),
#  ('Anne Vincent is a woman who has modern ideas about', 1),
#  ('Yvonne Valbret (Garbo) is a Parisian kept woman wh', 1),
#  ('Rodney Martin sets up a soap business to rival his', 1),
#  ('Lord Robert Brummell (William Haines), a bachelor ', 1),
#  ('Arthur Parker (Robert McWade) is a wealthy steel m', 1),
#  ('Young florist Kathleen Storm (Sylvia Sidney) is in', 1),
#  ('Sir Gerald Courtney (Gilbert Emery) is an aristocr', 1),
#  ('After World War I, pilots Cary Lockwood (Richard B', 1),
#  ('Sarah Austin (Edna May Oliver) runs a boarding hou', 1),
#  ('Ivy Stevens (Joan Crawford) is a cafe entertainer ', 1),
#  ('Sheepish bookstore employee John Miller has become', 1),
#  ('Richard "Dickie" Smith (Edward Everett Horton), is', 1),
#  ('Recovering from a World War I head wound, soldier ', 1),
#  ('In San Francisco, private investigator Sam Spade (', 1),
#  ('Raymond Dabney (Montgomery) returns to a mixed rea', 1),
#  ("In 1930's Paris, American Michael Trevor (William ", 1),
#  ('In 1917, France is embroiled in World War I. Duboi', 1),
#  ('Julia Cavanaugh is a formerly rich socialite who i', 1),
#  ('Millie (Helen Twelvetrees) is a naive young woman ', 1),
#  ('Florence Fallon is outraged when church elders, in', 1),
#  ('On board an ocean liner to America, four stowaways', 1),
#  ('El Brendel plays the dual role of Silent McGee, a ', 1),
#  ('In Panama, infamous nightclub hostess Carlotta (Ta', 1),
#  ('Attorney Alan Ward (Paul Page) is fed up with the ', 1),
#  ('A young woman, Jerry Girard (Frances Dee) is pushe', 1),
#  ('Lora Hart applies for a job as a trainee nurse in ', 1),
#  ('In 1929, Bill White (Grant Withers), is a railroad', 1),
#  ('Two cowboy friends, Jeff (J. Farrell MacDonald) an', 1),
#  ('During Prohibition, Laurel and Hardy are sent to p', 1),
#  ('Jeffrey Haywood (Reginald Denny) wants to get marr', 1),
#  ('Aggie Bruno (Cora Witherspoon) has had enough of h', 1),
#  ('Stewart "Stew" Smith (Robert Williams), ace report', 1),
#  ('Marian Martin (Joan Crawford) is a factory girl li', 1),
#  ('The snobbish Madame Pauline "Polly" Rochay operate', 1),
#  ('On an ocean liner from Colombo to Singapore, black', 1),
#  ('Princess Anne (Mary Astor) plans to run away with ', 1),
#  ('Millionaire playboy Fred White is attempting to ma', 1),
#  ('Gilda Karlson (Dorothy Mackaill) is a New Orleans ', 1),
#  ('Young Nell (Chandler) loses her job and home and h', 1),
#  ('Newspaper editor Mark Flint cares about only two t', 1),
#  ('Navy Lieutenant Greg Winters (Alan Hale) is found ', 1),
#  ('Two Union officers, Captain Lewis Dumont and his y', 1),
#  ('Bart Carter has sacrificed a writing career so he ', 1),
#  ('When neglected wife Alice (Karen Morley) decides t', 1),
#  ('Smiley Marsden (Ian Keith) is a bank-robber on the', 1),
#  ('Hughes plays Bob, a daredevil aviator in love with', 1),
#  ('Karim is the son of rajah and jewel merchant Hamid', 1),
#  ('Lisbeth is a modern woman who thinks that marriage', 1),
#  ('On a hot summer afternoon in New York, Emma Jones ', 1),
#  ('Snubbish, quick-tempered Henry Greene (George Meek', 1),
#  ('Three friends who work on the Coney Island boardwa', 1),
#  ('Helga Ohlin (Greta Garbo) is an illegitimate child', 1),
#  ('Bud Doyle is a jockey who has discovered the secre', 1),
#  ('Aged emissary Hitu arrives by Western sailing ship', 1),
#  ('Nancy Courtney, a once wealthy socialite, has had ', 1),
#  ('Socialite Valentine "Val" Winters (Joan Crawford) ', 1),
#  ('Helga Larson Hanson is living in Sweden, but is en', 1),
#  ('Young Tommy Jordan (Eddie Quillan) is sent for a r', 1),
#  ('Nella Vargo (Swanson) is a Hungarian prima donna w', 1),
#  ('Required to travel to India for a year to oversee ', 1),
#  ('While waiting to see the owner of the store who is', 1),
#  ('Suave English thief Barrington Hunt (Ronald Colman', 1),
#  ('Bob Marshall gets a promotion at a newspaper thank', 1),
#  ('Set on the coast of Newfoundland, a rivalry develo', 1),
#  ('Jerry Stevens is a Chicago millionaire whose fianc', 1),
#  ('A young man returns from Europe after several year', 1),
#  ('The film opens at the end of World War I, with lif', 1),
#  ('Two sisters from Indiana, Mae and June Thorpe, mov', 1),
#  ('When martial law is declared in Russia, all Jews a', 1),
#  ('Jim Donovan (Richard Dix) is a two-bit mob leader ', 1),
#  ('Cocky Tommy Connors (Spencer Tracy) is sentenced f', 1),
#  ('Jack Harrowby (Basil Rathbone) believes he is draw', 1),
#  ('Peter Piper (Charles Farrell) and his girlfriend S', 1),
#  ('Mike Harvey (Cromwell) and Betty Cameron (Wilson) ', 1),
#  ("College football hero Gary King's life changes for", 1),
#  ('A Russian woman with a forged passport attempts to', 1),
#  ('In the Great Depression era, the Board of Director', 1),
#  ('Tom Collier (Leslie Howard) is a book publisher wh', 1),
#  ('A radio writer is tricked into confessing — on the', 1),
#  ('Budapest bar entertainer Zara (Greta Garbo) is a d', 1),
#  ('Bud Reeves is an innocent young man who once lived', 1),
#  ('Alvin Roberts (Lee Tracy) feuds with Bunny Harmon ', 1),
#  ('The movie begins with seven American students trav', 1),
#  ('A young and honest New York Police Department dete', 1),
#  ('Haunted by the memory of Walter Holderlin, a soldi', 1),
#  ('Earl Tinker (Will Rogers) goes on a Mediterranean ', 1),
#  ('Max Clement and his father Florian, short of money', 1),
#  ("Marvin Blake is a sharecropper's son who wants to ", 1),
#  ('A wild young woman, Nasa Springer (Clara Bow), bor', 1),
#  ('Parisian cabaret performer Lilli de Rousseau (Bill', 1),
#  ('Jim Madden, a Texas Ranger, is gunned down while i', 1),
#  ('The film begins in a prospering New York in 1873. ', 1),
#  ('Dan Alton (Hoot Gibson) is a con artist, posing as', 1),
#  ('Linda Gault comes from a poverty-stricken family a', 1),
#  ('A pushy newspaper reporter Eddie Crane (Ned Sparks', 1),
#  ('In Naples, disgraced London barrister James "Jim" ', 1),
#  ('The story takes place at a downtown dance hall in ', 1),
#  ('Tim Madigan (Tim McCoy), a cowboy coming to the ai', 1),
#  ('Charles Sturm (Laughton) is a naval commander whos', 1),
#  ('Orville "Gabby" Denton is an alcoholic drifter wit', 1),
#  ('In England a group of sweepstakes winners are invi', 1),
#  ('The movie stars Spencer Tracy as a policeman who b', 1),
#  ("The film opens with Baron Von Burgen's head butler", 1),
#  ('Impoverished Count von Dopenthal (Marshall) plans ', 1),
#  ('Spoiled socialite Carol Morgan (Bankhead), romping', 1),
#  ('Two people leave the US Navy after having served t', 1),
#  ('During spring the flowers, mushrooms, and trees do', 1),
#  ('In 1906 San Francisco, Frisco Jenny Sandoval (Ruth', 1),
#  ('Doctor Otternschlag, a disfigured veteran of World', 1),
#  ('Jean, Polaire, and Schatze are ex-showgirls who pu', 1),
#  ('The plumber Mendel Marantz, a passionate inventor,', 1),
#  ('The film centers around brutal conditions in a pri', 1),
#  ('When orphaned Jimmy Mason is taken in by his Aunt ', 1),
#  ('Based on the novel Heritage of the Desert by Zane ', 1),
#  ('Gar Evans (William Powell) agrees to promote Ginsb', 1),
#  ('The film revolves around college football and a ga', 1),
#  ('A pretty young bank clerk, Ruth Brock (Nancy Carro', 1),
#  ('Tony Ametto, a young steel-worker with immigrant p', 1),
#  ('Sergeant James Allen (Muni) returns to civilian li', 1),
#  ('Shipwrecked traveler Edward Parker (Richard Arlen)', 1),
#  ('When his submarine, S89, is sunk by an excursion b', 1),
#  ('A doctor, Lyle Talbot as Dr. Robert Cromwell, is c', 1),
#  ('"Deadlegs" Flint, an embittered paraplegic who liv', 1),
#  ('Middle-aged Mrs. Livingston Baldwin Crane (Edna Ma', 1),
#  ('Although she is an heiress and quite lovely, Venic', 1),
#  ('The movie presents the life in a prison where men ', 1),
#  ('Anton Adam is a lawyer who has just got a client a', 1),
#  ('At a maternity hospital, future fathers pace the c', 1),
#  ('Ronald and Betty plan to elope, but are overheard ', 1),
#  ("At Goro's Tea House, we are introduced to Cho-Cho ", 1),
#  ('A small-town delivery boy Merton Gill (Stuart Erwi', 1),
#  ('Manhattan Tower is about a couple by the names of ', 1),
#  ('A disgraced doctor (Nagel) exiles himself to the S', 1),
#  ('Lois Ames (Kay Francis) is the editor of 400 Magaz', 1),
#  ('While giving a private performance for a visiting ', 1),
#  ('Though a lowly Chicago street cleaner, Swedish imm', 1),
#  ('In this wisecracking comedy, Dan Dolan (Spencer Tr', 1),
#  ('A destitute Marthe Preston is in dire straits in P', 1),
#  ('While visiting the mythical country of Klopstokia ', 1),
#  ('Helen Steele (Claudette Colbert) is bored to death', 1),
#  ('The film opens with Ruth Earlton and her fiance Dr', 1),
#  ('Harold Hall, a young man with little or no acting ', 1),
#  ('The film opens with a title card that reads "From ', 1),
#  ("Tom Reed's (Tom Mix) famous traveling Wild West sh", 1),
#  ('Mr. and Mrs. Thomas are affluent New Yorkers who a', 1),
#  ("On a cold winter's night outside Happy's Nightclub", 1),
#  ('Card sharp "Babe" Stewart (Clark Gable) and his cr', 1),
#  ('The departure of an ocean liner is held up to wait', 1),
#  ('The immense success of The Jazz Singer, the first ', 1),
#  ('Dan Hardesty (William Powell) is an escaped murder', 1),
#  ('First Mate Woolf Barstow is a corrupt merchant mar', 1),
#  ('After becoming involved in a killing, Kiddo gets o', 1),
#  ('Paris plumber Elmer Tuttle is enlisted by socialit', 1),
#  ('The Phantom President tells the fictional story of', 1),
#  ('A once popular actor, Nat Barry (played by Henry B', 1),
#  ('When a traveling circus arrives in a small town, t', 1),
#  ('Always looking for an angle, "Knucks" McGloin purc', 1),
#  ('A westbound ship en route to Apia, Samoa, is tempo', 1),
#  ('The highly fictionalized story takes place in the ', 1),
#  ('On a rubber plantation in French Indochina during ', 1),
#  ('Lilian "Lil" Andrews (Jean Harlow) is a young woma', 1),
#  ('New York City socialite Caroline Grannard and her ', 1),
#  ('John Drury (John Wayne) is passing through when to', 1),
#  ('Buck Randall (Buck Jones), a carefree cowboy whose', 1),
#  ('When stage actress Judy Carroll testifies on behal', 1),
#  ('When Russian revolutionaries overrun his country e', 1),
#  ('Kansas farmer Yates Martin (Edward G. Robinson) up', 1),
#  ('Doris Blake (Carole Lombard) works as a top model ', 1),
#  ('Bert "Speed" Condon (Richard Arlen) is the star of', 1),
#  ('In 1917, lifeguards Wilkie (Spencer Tracy) and Mit', 1),
#  ('The film depicts the aspirations and lives of seve', 1),
#  ('John Carteret (Leslie Howard) is a wealthy man wit', 1),
#  ('Prof. Post (Buster Keaton) is a shy Classics profe', 1),
#  ('John Barrymore plays near-alcoholic defense attorn', 1),
#  ('A man whose wife has deserted him winds up saving ', 1),
#  ('A young dress designer marries an insurance agent.', 1),
#  ('Gordon Shaw was a flyer who was shot down and kill', 1),
#  ('Henry Wilton is a successful financier who is retu', 1),
#  ('Felix \'"Felixel" Klauber (Ricardo Cortez), a brill', 1),
#  ('James Parker (C. Aubrey Smith) and Harry Holt (Nei', 1),
#  ('When a veteran cab driver, Pop Riley (Guy Kibbee),', 1),
#  ('Calvin Jones (Joe E. Brown), a naive cowboy from T', 1),
#  ('Pecos Grant rides into a strange town only to find', 1),
#  ('Small-town church organist Marion Cullen (Young) f', 1),
#  ('When wealthy Henry Davidson dies, he leaves all hi', 1),
#  ('Distracted just before the fight by the news that ', 1),
#  ('Thirteen women, who were sorority sisters at the a', 1),
#  ("When Claire Mathewson's husband Stephen comes back", 1),
#  ('The plot concerns a one-handed tuna fisherman name', 1),
#  ('A young man (Tom Brown) attends Culver Military Ac', 1),
#  ('Lawyer Dave Norton offers a settlement for the des', 1),
#  ('Rancher Tim Clark borrows money from Bob Russell, ', 1),
#  ('Several hundred extras appear in the courtroom seq', 1),
#  ('Charles "Chick" Miller (Douglas Fairbanks, Jr.) is', 1),
#  ('Pat and Max are in love and share an intimate rela', 1),
#  ('New York City streetwalker Mae (Carole Lombard) is', 1),
#  ('Button Gwinnett Brown (Lee Tracy) is a new congres', 1),
#  ('Returning back to United States from Europe, a wom', 1),
#  ('In the early 20th Century, with the Prohibition Er', 1),
#  ('Brown Derby waitress Mary Evans (Constance Bennett', 1),
#  ('Jacques Costaud, a French war veteran is sentenced', 1),
#  ('On her arrival in Haiti, Madeleine Short (Madge Be', 1),
#  ('Joe Holt works for the Armstrong Rubber Goods comp', 1),
#  ('With the outbreak of World War I, a young woman (C', 1),
#  ("Agnes Appleby (Wynne Gibson), waitress at Nick's R", 1),
#  ('In World War I, pilot Bob King is shot and killed ', 1),
#  ('Ann Carver (Fay Wray) and Bill Graham (Gene Raymon', 1),
#  ('After a military officer (Bruce Cabot) gets Ann Vi', 1),
#  ('Lily Powers works for her mean father, Nick, in a ', 1),
#  ('A beautiful English socialite, Diana Standing (Myr', 1),
#  ('Small town girl Letty Lawson (Madge Evans) moves t', 1),
#  ('Dying gangster Joe Valerie (Frank Reicher) reveals', 1),
#  ('Set during the Great Depression, Blondie Johnson q', 1),
#  ('Rodney Deane (Gene Raymond) is a rich playboy who ', 1),
#  ('Married chorus girl rides scandal to stardom.', 1),
#  ('Brash detective Butch Saunders is demoted from the', 1),
#  ("During a European train journey, a nobleman's butl", 1),
#  ('An ambitious mechanic is tempted to desert his won', 1),
#  ('Taxi dancer Madeleine McGonegle (Nancy Carroll) at', 1),
#  ('When news that several paintings by deceased artis', 1),
#  ('In London Monica (Helen Chandler) and her boyfrien', 1),
#  ("Kelly's daughter falls for a revenue agent, and hi", 1),
#  ('Calvert College begins taking football more seriou', 1),
#  ('The plot revolves around the convention of the Hon', 1),
#  ('The story focuses on several days in a critical ju', 1),
#  ('The film involves an extramarital encounter that l', 1),
#  ('Scientists discover that a violent storm is headin', 1),
#  ('In the early 18th century, the bandit Fra Diavolo ', 1),
#  ('The film concerns itself with the adventures of tw', 1),
#  ("Molly Gilbert won't accept a marriage proposal fro", 1),
#  ('Teacher Andy is fixated on both Dora who runs a ba', 1),
#  ('The wealthy Mrs. Teasdale (Margaret Dumont) insist', 1),
#  ('Elmer Kane (Joe E. Brown) is a rookie ballplayer w', 1),
#  ('At a Baptist prayer meeting, the preacher leads a ', 1),
#  ('Kurt Anderson is the ruthless, hard-driving genera', 1),
#  ('Mala is a member of an unspecified Eskimo tribe li', 1),
#  ('Helen Bauer (Bette Davis) is a glamorous, successf', 1),
#  ('Fast Workers is set in the early 1930s, in the tim', 1),
#  ('The "Black Cats", who are part of the Aerial Circu', 1),
#  ('Retired Papa Strauss, a widower, who has been a su', 1),
#  ('An ambitious grain trader Chris Martin (Chester Mo', 1),
#  ('Chester Hamilton (Sidney Blackmer) is sent to "ali', 1),
#  ('Mae Knight (Joan Blondell) and Sadie Appleby (Glen', 1),
#  ('Bill Allen (William Gargan) and his friend, Mike (', 1),
#  ('A veteran of World War I, Thomas Holmes (Richard B', 1),
#  ('Dick Wallace, portrayed by a 26-year-old John Wayn', 1),
#  ('San Diego Standard reporter H. Joseph Miller (Ben ', 1),
#  ('A playwright discovers an actress to star in his l', 1),
#  ('John Hayden (Robinson), owner of a Chicago meat-pa', 1),
#  ('\r\nUnhappily married, a man and a woman try to main', 1),
#  ('A bomb planted on board a ship may go off at any m', 1),
#  ('A former circus performer, Ken Kenton becomes pers', 1),
#  ('Phillip (Arliss), the figurehead monarch of an unn', 1),
#  ('The story focuses on Apple Annie (May Robson), an ', 1),
#  ('Easter, a soldier of fortune and gunrunner, leaves', 1),
#  ("O'Brien plays an Irish mine worker, Barney Slaney.", 1),
#  ('Southpaw boxer Jimmy Dolan believes in clean livin', 1),
#  ('With his upscale department store steadily losing ', 1),
#  ('The film concerns an imprisoned bootlegger (Spence', 1),
#  ('The story is based on the requirement of Spanish l', 1),
#  ('Based upon a novel by Zane Grey, Man of the Forest', 1),
#  ('A couple of bunglers (Jimmy Durante and Jack Pearl', 1),
#  ('The story begins with an indifferent Mary Martin (', 1),
#  ('Laurel and Hardy play two policemen on night patro', 1),
#  ('The plot involves a newspaper reporter (Ed Sulliva', 1),
#  ('Big-game hunter and wealthy zoologist Eric Gorman ', 1),
#  ('Ivan Igor (Lionel Atwill) is a sculptor who operat', 1),
#  ('In South America, the daunting mountains and dange', 1),
#  ('Police have been vainly searching the countryside ', 1),
#  ('Anna (Irene Dunne) yearns to escape from Pittsburg', 1),
#  ('Unlike in the Zweig story, in the end Emerson ackn', 1),
#  ('Just after her wedding, American hardware heiress ', 1),
#  ('United States Marine Corps Lieutenants and pilots ', 1),
#  ('When Sylvia Day (Mae Clarke) is caught trying to p', 1),
#  ('Mary Holmes (MacKellar), once a famous opera star ', 1),
#  ('Four mail order brides from New Orleans and a youn', 1),
#  ('After getting out of prison, Danny Kean (James Cag', 1),
#  ('Andrew Poole (Roland Young) has lost his wealth in', 1),
#  ...]

# %%
df[df["Plot"].str.contains("The plot revolves around the players on a hockey t")]
# Out:
#               Title                                               Plot   Genre
# 13302      les boys  The plot revolves around the players on a hock...  comedy
# 13307   les boys ii  The plot revolves around the players on a hock...  comedy
# 13343  les boys iii  The plot revolves around the players on a hock...  comedy
# 13385   les boys iv  The plot revolves around the players on a hock...  comedy

# %%
Counter(df["Genre"]).most_common()
# Out:
# [('drama', 5590),
#  ('comedy', 4170),
#  ('action', 3482),
#  ('thriller', 1935),
#  ('romance', 888),
#  ('animation', 579)]

# %%
labels = list(set(df["Genre"]))
labels
# Out:
# ['drama', 'comedy', 'animation', 'romance', 'thriller', 'action']

# %%
id2label = {k:v for k,v in enumerate(labels)}
label2id = {v:k for k,v in enumerate(labels)}
label2id
# Out:
# {'drama': 0,
#  'comedy': 1,
#  'animation': 2,
#  'romance': 3,
#  'thriller': 4,
#  'action': 5}

# %%
# Check the number of unique genres in df_20["genre"]
num_unique_genres = df["Genre"].nunique()

# Check the number of unique labels in the label2id mapping
num_unique_labels = len(label2id)

# Ensure consistency
if num_unique_genres != num_unique_labels:
    raise ValueError("Number of unique genres in df_20 does not match the number of unique labels in the label2id mapping.")

# If they match, proceed with creating the "label" column
df["label"] = df["Genre"].apply(lambda x: label2id[x])

# %%
df.head()
# Out:
#                              Title  \
# 0          the great train robbery
# 1                  the suburbanite
# 2  how brown saw the baseball game
# 3         the adventures of dollie
# 4                  the black viper
#
#                                                 Plot   Genre  label
# 0  The film opens with two bandits breaking into ...  action      5
# 1  The film is about a family who move to the sub...  comedy      1
# 2  Before heading out to a baseball game at a nea...  comedy      1
# 3  On a beautiful summer day a father and mother ...   drama      0
# 4  A thug accosts a girl as she leaves her workpl...   drama      0

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_train, test_size=0.25, random_state=42)

# %%
from datasets import Features, ClassLabel, Value, Dataset, DatasetDict

# Define the schema to match your DataFrame columns
ds_features = Features({
    "Title": Value("string"),
    "Plot": Value("string"),
    "Genre": Value("string"),
    "label": ClassLabel(names=labels)
})

# Create the Dataset from your DataFrame with the updated schema
dataset = DatasetDict({
    "train": Dataset.from_pandas(df_train.reset_index(drop=True), features=ds_features),
    "valid": Dataset.from_pandas(df_val.reset_index(drop=True), features=ds_features),
    "test": Dataset.from_pandas(df_test.reset_index(drop=True), features=ds_features)
})

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Title', 'Plot', 'Genre', 'label'],
#         num_rows: 9986
#     })
#     valid: Dataset({
#         features: ['Title', 'Plot', 'Genre', 'label'],
#         num_rows: 3329
#     })
#     test: Dataset({
#         features: ['Title', 'Plot', 'Genre', 'label'],
#         num_rows: 3329
#     })
# })

# %%
Counter(df["Genre"]).most_common()
# Out:
# [('drama', 5590),
#  ('comedy', 4170),
#  ('action', 3482),
#  ('thriller', 1935),
#  ('romance', 888),
#  ('animation', 579)]

# %%
from transformers import AutoTokenizer

model_ckpt = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def tokenize(batch):
    return tokenizer(batch["Plot"], padding=True, truncation=True)

# %%
from datasets import load_dataset
dataset_encoded = dataset.map(tokenize, batched=True, batch_size=None)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
print(dataset_encoded["train"].column_names)
# Out:
# ['Title', 'Plot', 'Genre', 'label', 'input_ids', 'token_type_ids', 'attention_mask']

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from transformers import AutoModelForSequenceClassification, AutoConfig

num_labels = len(labels)

config = (AutoConfig
          .from_pretrained(model_ckpt, num_labels=num_labels, 
                           label2id=label2id, id2label=id2label))

model = (AutoModelForSequenceClassification
         .from_pretrained(model_ckpt, config=config)
         .to(device))
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from sklearn.metrics import accuracy_score, f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels, preds, average="weighted")
    acc = accuracy_score(labels, preds)
    return {"accuracy": acc, "f1": f1}

# %%
from transformers import Trainer, TrainingArguments

batch_size = 16
logging_steps = len(dataset_encoded["train"]) // batch_size
model_name = f"{model_ckpt}-finetuned"
training_args = TrainingArguments(output_dir=model_name,
                                  num_train_epochs=4,
                                  learning_rate=2e-5,
                                  per_device_train_batch_size=batch_size,
                                  per_device_eval_batch_size=batch_size,
                                  weight_decay=0.01,
                                  evaluation_strategy="epoch",
                                  disable_tqdm=False,
                                  logging_steps=logging_steps,
#                                   push_to_hub=True, 
                                  log_level="error",
                                  save_total_limit=1)
# Out:
# 2024-02-18 02:26:50.037624: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-18 02:26:50.037728: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-18 02:26:50.323077: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from transformers import Trainer

trainer = Trainer(model=model, args=training_args, 
                  compute_metrics=compute_metrics,
                  train_dataset=dataset_encoded["train"],
                  eval_dataset=dataset_encoded["valid"],
                  tokenizer=tokenizer)
trainer.train();
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.16.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240218_022716-qt5uy9r8</code>
# Syncing run <strong><a href='https://wandb.ai/mostafa-maroof/huggingface/runs/qt5uy9r8' target="_blank">abundant-dumpling-6</a></strong> to <a href='https://wandb.ai/mostafa-maroof/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mostafa-maroof/huggingface' target="_blank">https://wandb.ai/mostafa-maroof/huggingface</a>
#  View run at <a href='https://wandb.ai/mostafa-maroof/huggingface/runs/qt5uy9r8' target="_blank">https://wandb.ai/mostafa-maroof/huggingface/runs/qt5uy9r8</a>
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='1252' max='1252' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1252/1252 38:38, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.902531</td>
#       <td>0.665966</td>
#       <td>0.652486</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.953800</td>
#       <td>0.850397</td>
#       <td>0.685191</td>
#       <td>0.681445</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.953800</td>
#       <td>0.876272</td>
#       <td>0.686392</td>
#       <td>0.684821</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.532100</td>
#       <td>0.898147</td>
#       <td>0.687293</td>
#       <td>0.684337</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '

# %%
preds_output = trainer.predict(dataset_encoded["valid"])
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '

# %%
preds_output.metrics
# Out:
# {'test_loss': 0.898147463798523,
#  'test_accuracy': 0.6872934815259838,
#  'test_f1': 0.684336972258498,
#  'test_runtime': 65.3512,
#  'test_samples_per_second': 50.94,
#  'test_steps_per_second': 1.607}

# %%
y_preds = np.argmax(preds_output.predictions, axis=1)
y_valid = np.array(df_val["label"])

# %%
print(classification_report(y_valid,y_preds, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#        drama       0.68      0.72      0.70      1131
#       comedy       0.73      0.68      0.70       813
#    animation       0.80      0.75      0.77       122
#      romance       0.50      0.31      0.39       181
#     thriller       0.62      0.66      0.64       373
#       action       0.70      0.75      0.72       709
#
#     accuracy                           0.69      3329
#    macro avg       0.67      0.64      0.65      3329
# weighted avg       0.68      0.69      0.68      3329

# %%
text = "Thor enlists the help of Valkyrie, Korg and ex-girlfriend Jane Foster to fight Gorr the God Butcher, who intends to make the gods extinct."

encoding = tokenizer(text,  padding=True, truncation=True, return_tensors="pt")
encoding = {k: v.to(trainer.model.device) for k,v in encoding.items()}

outputs = trainer.model(**encoding)

# %%
logits = outputs.logits
logits.shape
# Out:
# torch.Size([1, 6])

# %%
predictions = torch.nn.functional.softmax(logits.squeeze().cpu(), dim=-1)
predictions
# Out:
# tensor([0.0120, 0.0584, 0.0386, 0.0055, 0.0336, 0.8519],
#        grad_fn=<SoftmaxBackward0>)

# %%
id2label[int(predictions.argmax())]
# Out:
# 'action'

# %%
text = "After first meeting at a summer camp together with their parents, Emma Kurtzman and Adam Franklin run into each other a few times as independent people but never keep in touch. Emma is a doctor in Los Angeles, and Adam is a production assistant for a musical television show. "

encoding = tokenizer(text,  padding=True, truncation=True, return_tensors="pt")
encoding = {k: v.to(trainer.model.device) for k,v in encoding.items()}

outputs = trainer.model(**encoding)

# %%
logits = outputs.logits
logits.shape
# Out:
# torch.Size([1, 6])

# %%
predictions = torch.nn.functional.softmax(logits.squeeze().cpu(), dim=-1)
predictions
# Out:
# tensor([0.0404, 0.9259, 0.0055, 0.0234, 0.0029, 0.0019],
#        grad_fn=<SoftmaxBackward0>)

# %%
id2label[int(predictions.argmax())]
# Out:
# 'comedy'

# %%
text = "Matthew is an American exchange student who has come to Paris to study French. While at the Cinémathèque Française protesting the firing of Henri Langlois, he meets the free-spirited twins Théo and Isabelle. The three bond over a shared love of film. After dinner with their parents, Théo and Isabelle offer Matthew the chance to stay with them while their parents are on a trip. Matthew accepts, considering them his first French friends. "

encoding = tokenizer(text,  padding=True, truncation=True, return_tensors="pt")
encoding = {k: v.to(trainer.model.device) for k,v in encoding.items()}

outputs = trainer.model(**encoding)

# %%
logits = outputs.logits
logits.shape
# Out:
# torch.Size([1, 6])

# %%
predictions = torch.nn.functional.softmax(logits.squeeze().cpu(), dim=-1)
predictions
# Out:
# tensor([0.7530, 0.1671, 0.0043, 0.0634, 0.0070, 0.0051],
#        grad_fn=<SoftmaxBackward0>)

# %%
id2label[int(predictions.argmax())]
# Out:
# 'drama'
